# %% [markdown]
# The new version of this notebook works through the items I created for some American Indian areas via the TIGER web table, aligning with the Microsoft Planetary Computer source of U.S. Census data. I found that the GEOID values didn't line up exactly (there was an R suffix in the HTML table form of the records).
#
# The MPC source is different in that it is a blend of American Indian, Alaska Native, and Native Hawaiian Tribes and other entities. Ultimately, I need to revisit this with other sources of information, including connecting the dots with how Tribes are represented in Wikidata.

# %%
import planetary_computer
import pystac_client
import dask_geopandas
import pandas as pd

from wbmaker import WikibaseConnection

# %%
eew = WikibaseConnection('EEW')

# %%
# Select source item to process
source_item_id = eew.ref_lookup['American Indian, Alaskan Native, and Native Hawaiian lands from U.S. Census']
source_item = eew.wbi.item.get(source_item_id)

# %%
# Extract STAC connection details from source item
stac_source = source_item.claims.get_json()[eew.prop_lookup['STAC catalog URL']][0]
stac_catalog_url = stac_source['mainsnak']['datavalue']['value']
stac_collection_name = stac_source['qualifiers'][eew.prop_lookup['STAC Collection Name']][0]['datavalue']['value']
stac_item_name = stac_source['qualifiers'][eew.prop_lookup['STAC Item Name']][0]['datavalue']['value']

# %%
# Query STAC catalog for asset
stac_catalog = pystac_client.Client.open(
    stac_catalog_url,
    modifier=planetary_computer.sign_inplace,
)
stac_collection = stac_catalog.get_collection(stac_collection_name)
stac_asset = stac_collection.get_item(stac_item_name).assets["data"]

# %%
# Read source data and compute coordinates
gdf_aiannh = dask_geopandas.read_parquet(
    stac_asset.href,
    storage_options=stac_asset.extra_fields["table:storage_options"],
    calculate_divisions=True,
)
gdf_aiannh = gdf_aiannh.to_crs(epsg=4326).compute()
gdf_aiannh['coordinates'] = gdf_aiannh.to_crs('+proj=cea').geometry.centroid.to_crs(gdf_aiannh.crs)
gdf_aiannh['gnis_id'] = gdf_aiannh.AIANNHNS.astype(str)

# %%
# Lookup existing GEOID records
query_gnis = "PREFIX%20wd%3A%20%3Chttps%3A%2F%2Feew-edgi.wikibase.cloud%2Fentity%2F%3E%0APREFIX%20wdt%3A%20%3Chttps%3A%2F%2Feew-edgi.wikibase.cloud%2Fprop%2Fdirect%2F%3E%0A%0ASELECT%20%3Fitem%20%3FitemLabel%20%3Fgnis_id%20%3Fgeoid%0AWHERE%20%7B%0A%20%20%3Fitem%20wdt%3AP1%20wd%3AQ338%20.%0A%20%20%3Fitem%20wdt%3AP25%20%3Fgnis_id%20.%0A%20%20%3Fitem%20wdt%3AP36%20%3Fgeoid%20.%0A%20%20SERVICE%20wikibase%3Alabel%20%7B%20bd%3AserviceParam%20wikibase%3Alanguage%20%22en%22%20%7D%0A%7D%0A"
df_gnis_lookup = eew.wb_ref_data(query=query_gnis)
df_gnis_lookup["aiannh_qid"] = df_gnis_lookup.item.apply(lambda x: x.split('/')[-1])

existing_aiannh = pd.merge(
    left=gdf_aiannh[gdf_aiannh.gnis_id.isin(df_gnis_lookup.gnis_id)],
    right=df_gnis_lookup[["gnis_id","aiannh_qid","itemLabel","geoid"]],
    how="left",
    on="gnis_id"
).reset_index(drop=True)

new_aiannh = gdf_aiannh[~gdf_aiannh.gnis_id.isin(df_gnis_lookup.gnis_id)]

# %%
# Lookup QID for LSAD and merge with source data
query_lsad = "PREFIX%20wdt%3A%20%3Chttps%3A%2F%2Feew-edgi.wikibase.cloud%2Fprop%2Fdirect%2F%3E%0A%0ASELECT%20%3Flsad%20%3FlsadLabel%20%3FLSAD%0AWHERE%20%7B%0A%20%20%3Flsad%20wdt%3AP54%20%3FLSAD%20.%0A%20%20SERVICE%20wikibase%3Alabel%20%7B%20bd%3AserviceParam%20wikibase%3Alanguage%20%22en%22%20%7D%0A%7D"
df_lsad = eew.wb_ref_data(query=query_lsad)
df_lsad['lsad_qid'] = df_lsad.lsad.apply(lambda x: x.split('/')[-1])

# %%
existing_aiannh = pd.merge(
    left=existing_aiannh,
    right=df_lsad[["LSAD","lsad_qid","lsadLabel"]],
    how="left",
    on="LSAD"
)

# %%
references = eew.models.References()
references.add(
    eew.datatypes.Item(
        prop_nr=eew.prop_lookup['data source'],
        value=eew.ref_lookup['American Indian, Alaskan Native, and Native Hawaiian lands from U.S. Census']
    )
)
# Out:
# <References @3ab3a0 _References__references=[<Reference @3a99f0 _Reference__hash=None _Reference__snaks=<Snaks @3a8a60 snaks={'P6': [<Snak @3a9030 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 30255, 'id': 'Q30255'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>

# %%
for index, row in existing_aiannh.iterrows():
    item = eew.wbi.item.get(row.aiannh_qid)
    
    alias_list = [i["value"] for i in item.aliases.get_json()["en"]]
    if row.NAMELSAD not in alias_list:
        alias_list.append(row.NAMELSAD)
        item.aliases.set('en', alias_list)

    new_claims = eew.models.Claims()

    new_claims.add(
        eew.datatypes.ExternalID(
            prop_nr=eew.prop_lookup['TIGER GEOID'],
            value=row.GEOID,
            references=references
        )
    )

    new_claims.add(
        eew.datatypes.Item(
            prop_nr=eew.prop_lookup['Legal/Statistical Area Description'],
            value=row.lsad_qid,
            references=references
        )
    )

    item.claims.add(claims=new_claims)
    try:
        response = item.write(
            summary="Updated item with information from MPC source",
            clear=True
        )
        print("UPDATED:", row.itemLabel, response.id)
    except Exception as e:
        print("PROBLEM:", row.itemLabel)
# Out:
# UPDATED: Chemehuevi Reservation Q376
# UPDATED: Wells Colony Q636
# UPDATED: Colville Reservation Q385
# UPDATED: Tohono O'odham Nation Reservation Q615
# UPDATED: Uintah and Ouray Reservation Q627
# UPDATED: Guidiville Rancheria Q431
# UPDATED: Immokalee Reservation Q443
# UPDATED: Elk Valley Rancheria Q400
# UPDATED: Tonawanda Reservation Q616
# UPDATED: Pleasant Point Reservation Q533
# UPDATED: Zuni Reservation Q652
# UPDATED: Jamul Indian Village Q451
# UPDATED: Las Vegas Indian Colony Q470
# UPDATED: San Carlos Reservation Q564
# UPDATED: Upper Lake Rancheria Q629
# UPDATED: White Earth Reservation Q637
# UPDATED: Jackson Rancheria Q449
# UPDATED: Onondaga Nation Reservation Q518
# UPDATED: Fort Pierce Reservation Q421
# UPDATED: Navajo Nation Reservation Q506
# UPDATED: Stewarts Point Rancheria Q601
# UPDATED: Big Sandy Rancheria Q357
# UPDATED: Annette Island Reserve Q344
# UPDATED: Fort Sill Apache Indian Reservation Q422
# UPDATED: Yurok Reservation Q650
# UPDATED: Standing Rock Reservation Q599
# UPDATED: Quartz Valley Reservation Q544
# UPDATED: Acoma Pueblo Q339
# UPDATED: Tuscarora Nation Reservation Q625
# UPDATED: Santa Rosa Rancheria Q572
# UPDATED: Havasupai Reservation Q433
# UPDATED: Hoopa Valley Reservation Q437
# UPDATED: XL Ranch Rancheria Q642
# UPDATED: Carson Colony Q371
# UPDATED: Sauk-Suiattle Reservation Q578
# UPDATED: Fort Apache Reservation Q411
# UPDATED: Big Bend Rancheria Q353
# UPDATED: Picayune Rancheria Q529
# UPDATED: Cold Springs Rancheria Q382
# UPDATED: Inaja and Cosmit Reservation Q444
# UPDATED: Warm Springs Reservation Q635
# UPDATED: Fort Mojave Reservation Q419
# UPDATED: La Posta Indian Reservation Q464
# UPDATED: Timbi-Sha Shoshone Reservation Q614
# UPDATED: Hannahville Indian Community Q432
# UPDATED: Oil Springs Reservation Q514
# UPDATED: Klamath Reservation Q460
# UPDATED: Skokomish Reservation Q585
# UPDATED: Yerington Colony Q647
# UPDATED: Isleta Pueblo Q448
# UPDATED: Forest County Potawatomi Community Q410
# UPDATED: Chicken Ranch Rancheria Q378
# UPDATED: Table Bluff Reservation Q609
# UPDATED: Coeur d'Alene Reservation Q381
# UPDATED: Cow Creek Reservation Q390
# UPDATED: Shoalwater Bay Indian Reservation Q583
# UPDATED: Kaibab Indian Reservation Q455
# UPDATED: Hopi Reservation Q438
# UPDATED: Pine Ridge Reservation Q531
# UPDATED: Fort Independence Reservation Q416
# UPDATED: Lytton Rancheria Q484
# UPDATED: Augustine Reservation Q346
# UPDATED: Bridgeport Reservation Q363
# UPDATED: Montgomery Creek Rancheria Q500
# UPDATED: Fort Hall Reservation Q415
# UPDATED: Bishop Reservation Q359
# UPDATED: Picuris Pueblo Q530
# UPDATED: Wind River Reservation Q638
# UPDATED: Alturas Indian Rancheria Q343
# UPDATED: Blackfeet Indian Reservation Q360
# UPDATED: Mooretown Rancheria Q501
# UPDATED: Flathead Reservation Q408
# UPDATED: Lovelock Indian Colony Q479
# UPDATED: Duck Valley Reservation Q397
# UPDATED: Rosebud Indian Reservation Q558
# UPDATED: Fort Bidwell Reservation Q414
# UPDATED: Rumsey Indian Rancheria Q560
# UPDATED: Leech Lake Reservation Q472
# UPDATED: Pinoleville Rancheria Q532
# UPDATED: Dry Creek Rancheria Q396
# UPDATED: Sulphur Bank Rancheria Q604
# UPDATED: Cowlitz Reservation Q391
# UPDATED: Skull Valley Reservation Q586
# UPDATED: Grindstone Indian Rancheria Q430
# UPDATED: Lone Pine Reservation Q476
# UPDATED: Northwestern Shoshone Reservation Q512
# UPDATED: Nisqually Reservation Q508
# UPDATED: Jicarilla Apache Nation Reservation Q454
# UPDATED: Yankton Reservation Q644
# UPDATED: Lac Courte Oreilles Reservation Q465
# UPDATED: Taos Pueblo Q612
# UPDATED: Penobscot Reservation Q528
# UPDATED: Enterprise Rancheria Q403
# UPDATED: Oneida Indian Nation Reservation Q517
# UPDATED: Snoqualmie Reservation Q588
# UPDATED: Grand Portage Reservation Q426
# UPDATED: Turtle Mountain Reservation Q624
# UPDATED: Round Valley Reservation Q559
# UPDATED: Likely Rancheria Q473
# UPDATED: Chitimacha Reservation Q379
# UPDATED: Walker River Reservation Q634
# UPDATED: Jemez Pueblo Q452
# UPDATED: Roaring Creek Rancheria Q555
# UPDATED: Upper Skagit Reservation Q631
# UPDATED: Spokane Reservation Q594
# UPDATED: Lookout Rancheria Q477
# UPDATED: Viejas Reservation Q633
# UPDATED: Colusa Rancheria Q384
# UPDATED: Big Pine Reservation Q356
# UPDATED: Cahuilla Reservation Q367
# UPDATED: San Manuel Reservation Q567
# UPDATED: Lake Traverse Reservation Q469
# UPDATED: Tulalip Reservation Q620
# UPDATED: Crow Reservation Q394
# UPDATED: Bad River Reservation Q347
# UPDATED: Auburn Rancheria Q345
# UPDATED: Chehalis Reservation Q375
# UPDATED: Capitan Grande Reservation Q370
# UPDATED: Cortina Indian Rancheria Q388
# UPDATED: Cedarville Rancheria Q374
# UPDATED: Summit Lake Reservation Q605
# UPDATED: Campbell Ranch Q368
# UPDATED: Big Valley Rancheria Q358
# UPDATED: Yakama Nation Reservation Q643
# UPDATED: Sac and Fox Nation Reservation Q561
# UPDATED: Kickapoo (TX) Reservation Q459
# UPDATED: Mohegan Reservation Q499
# UPDATED: Santa Clara Pueblo Q571
# UPDATED: Santee Reservation Q576
# UPDATED: Lower Elwha Reservation Q481
# UPDATED: Mashantucket Pequot Reservation Q489
# UPDATED: Soboba Reservation Q589
# UPDATED: Ewiiaapaayp Reservation Q404
# UPDATED: Berry Creek Rancheria Q352
# UPDATED: Ho-Chunk Nation Reservation Q434
# UPDATED: Fort Belknap Reservation Q412
# UPDATED: Winnebago Reservation Q639
# UPDATED: Pueblo de Cochiti Q540
# UPDATED: Lower Brule Reservation Q480
# UPDATED: Port Gamble Reservation Q536
# UPDATED: Ontonagon Reservation Q519
# UPDATED: Manzanita Reservation Q487
# UPDATED: Morongo Reservation Q502
# UPDATED: Prairie Island Indian Community Q539
# UPDATED: Yomba Reservation Q648
# UPDATED: Laguna Pueblo Q468
# UPDATED: Gila River Indian Reservation Q424
# UPDATED: Pauma and Yuima Reservation Q526
# UPDATED: St. Croix Reservation Q597
# UPDATED: Susanville Indian Rancheria Q606
# UPDATED: Resighini Rancheria Q553
# UPDATED: Hopland Rancheria Q439
# UPDATED: Tampa Reservation Q611
# UPDATED: Coushatta Reservation Q389
# UPDATED: Lac Vieux Desert Reservation Q466
# UPDATED: Lower Sioux Indian Community Q482
# UPDATED: Fort Berthold Reservation Q413
# UPDATED: Coos, Lower Umpqua, and Siuslaw Reservation Q386
# UPDATED: Squaxin Island Reservation Q595
# UPDATED: Fort McDowell Yavapai Nation Reservation Q418
# UPDATED: Redding Rancheria Q550
# UPDATED: Nambe Pueblo Q504
# UPDATED: Coyote Valley Reservation Q392
# UPDATED: Fort McDermitt Indian Reservation Q417
# UPDATED: Fallon Paiute-Shoshone Colony Q405
# UPDATED: Eastern Cherokee Reservation Q399
# UPDATED: Alabama-Coushatta Reservation Q341
# UPDATED: Omaha Reservation Q515
# UPDATED: Isabella Reservation Q447
# UPDATED: Agua Caliente Indian Reservation Q340
# UPDATED: Los Coyotes Reservation Q478
# UPDATED: Twenty-Nine Palms Reservation Q626
# UPDATED: Siletz Reservation Q584
# UPDATED: Lac du Flambeau Reservation Q467
# UPDATED: Ute Mountain Reservation Q632
# UPDATED: Bay Mills Reservation Q350
# UPDATED: Santa Rosa Reservation Q573
# UPDATED: Ramona Village Q547
# UPDATED: Benton Paiute Reservation Q351
# UPDATED: Cattaraugus Reservation Q373
# UPDATED: Tunica-Biloxi Reservation Q622
# UPDATED: Narragansett Reservation Q505
# UPDATED: Coquille Reservation Q387
# UPDATED: Paiute (UT) Reservation Q521
# UPDATED: Prairie Band of Potawatomi Nation Reservation Q538
# UPDATED: Match-e-be-nash-she-wish Band of Pottawatomi Reservation Q490
# UPDATED: Reno-Sparks Indian Colony Q552
# UPDATED: Southern Ute Reservation Q592
# UPDATED: Nooksack Reservation Q509
# UPDATED: Maricopa (Ak Chin) Indian Reservation Q488
# UPDATED: Tule River Reservation Q621
# UPDATED: Nez Perce Reservation Q507
# UPDATED: Elko Colony Q401
# UPDATED: Mescalero Reservation Q493
# UPDATED: Indian Township Reservation Q445
# UPDATED: Bois Forte Reservation Q362
# UPDATED: Catawba Reservation Q372
# UPDATED: Muckleshoot Reservation Q503
# UPDATED: Smith River Rancheria Q587
# UPDATED: Middletown Rancheria Q495
# UPDATED: Makah Indian Reservation Q485
# UPDATED: Red Cliff Reservation Q548
# UPDATED: Pala Reservation Q523
# UPDATED: Blue Lake Rancheria Q361
# UPDATED: Sault Ste. Marie Reservation Q579
# UPDATED: Swinomish Reservation Q607
# UPDATED: Sokaogon Chippewa Community Q590
# UPDATED: Cabazon Reservation Q366
# UPDATED: Campo Indian Reservation Q369
# UPDATED: Winnemucca Indian Colony Q640
# UPDATED: Santa Ynez Reservation Q574
# UPDATED: Duckwater Reservation Q398
# UPDATED: Port Madison Reservation Q537
# UPDATED: San Pasqual Reservation Q568
# UPDATED: Laytonville Rancheria Q471
# UPDATED: Miccosukee Reservation Q494
# UPDATED: Sac and Fox/Meskwaki Settlement Q562
# UPDATED: Stewart Community Q600
# UPDATED: Ely Reservation Q402
# UPDATED: Sandia Pueblo Q569
# UPDATED: Stillaguamish Reservation Q602
# UPDATED: Stockbridge Munsee Community Q603
# UPDATED: Fond du Lac Reservation Q409
# UPDATED: Zia Pueblo Q651
# UPDATED: Sherwood Valley Rancheria Q581
# UPDATED: Big Cypress Reservation Q354
# UPDATED: Pokagon Reservation Q535
# UPDATED: Little River Reservation Q474
# UPDATED: Quinault Reservation Q546
# UPDATED: La Jolla Reservation Q463
# UPDATED: L'Anse Reservation Q462
# UPDATED: Goshute Reservation Q425
# UPDATED: Allegany Reservation Q342
# UPDATED: Cocopah Reservation Q380
# UPDATED: Iowa (KS-NE) Reservation Q446
# UPDATED: St. Regis Mohawk Reservation Q598
# UPDATED: Lummi Reservation Q483
# UPDATED: Hualapai Indian Reservation Q441
# UPDATED: Manchester-Point Arena Rancheria Q486
# UPDATED: Sycuan Reservation Q608
# UPDATED: San Ildefonso Pueblo Q566
# UPDATED: Dresslerville Colony Q395
# UPDATED: Santa Ysabel Reservation Q575
# UPDATED: Pechanga Reservation Q527
# UPDATED: Yavapai-Prescott Reservation Q646
# UPDATED: Brighton Reservation Q364
# UPDATED: Houlton Maliseet Reservation Q440
# UPDATED: Fallon Paiute-Shoshone Reservation Q406
# UPDATED: San Felipe Pueblo Q565
# UPDATED: Santa Ana Pueblo Q570
# UPDATED: Kalispel Reservation Q456
# UPDATED: Yavapai-Apache Nation Reservation Q645
# UPDATED: Paskenta Rancheria Q525
# UPDATED: Jamestown S'Klallam Reservation Q450
# UPDATED: Shingle Springs Rancheria Q582
# UPDATED: Quileute Reservation Q545
# UPDATED: Puyallup Reservation Q542
# UPDATED: Karuk Reservation Q457
# UPDATED: Kootenai Reservation Q461
# UPDATED: Crow Creek Reservation Q393
# UPDATED: Ohkay Owingeh Q513
# UPDATED: Grand Traverse Reservation Q428
# UPDATED: South Fork Reservation Q591
# UPDATED: Pascua Pueblo Yaqui Reservation Q524
# UPDATED: Tesuque Pueblo Q613
# UPDATED: Santo Domingo Pueblo Q577
# UPDATED: Menominee Reservation Q491
# UPDATED: Moapa River Indian Reservation Q498
# UPDATED: Rocky Boy's Reservation Q557
# UPDATED: Oneida (WI) Reservation Q516
# UPDATED: Flandreau Reservation Q407
# UPDATED: Colorado River Indian Reservation Q383
# UPDATED: Mesa Grande Reservation Q492
# UPDATED: Mississippi Choctaw Reservation Q497
# UPDATED: Little Traverse Bay Reservation Q475
# UPDATED: Huron Potawatomi Reservation Q442
# UPDATED: Burns Paiute Indian Colony Q365
# UPDATED: Greenville Rancheria Q429
# UPDATED: Table Mountain Rancheria Q610
# UPDATED: Hoh Indian Reservation Q435
# UPDATED: Woodfords Community Q641
# UPDATED: Pyramid Lake Paiute Reservation Q543
# UPDATED: Fort Yuma Indian Reservation Q423
# UPDATED: Upper Sioux Community Q630
# UPDATED: Ysleta del Sur Pueblo Q649
# UPDATED: Pueblo of Pojoaque Q541
# UPDATED: Salt River Reservation Q563
# UPDATED: Trinidad Rancheria Q619
# UPDATED: Robinson Rancheria Q556
# UPDATED: Tonto Apache Reservation Q617
# UPDATED: Poarch Creek Reservation Q534
# UPDATED: Mille Lacs Reservation Q496
# UPDATED: Hollywood Reservation Q436
# UPDATED: Shakopee Mdewakanton Sioux Community Q580
# UPDATED: Barona Reservation Q348
# UPDATED: Tuolumne Rancheria Q623
# UPDATED: Kickapoo (KS) Reservation Q458
# UPDATED: Battle Mountain Reservation Q349
# UPDATED: Grand Ronde Community Q427
# UPDATED: Big Lagoon Rancheria Q355
# UPDATED: Jena Band of Choctaw Reservation Q453

# %%
new_aiannh = pd.merge(
    left=new_aiannh,
    right=df_lsad[["LSAD","lsad_qid","lsadLabel"]],
    how="left",
    on="LSAD"
)

# %%
def set_instance_of(LSAD):
    if LSAD == "78":
        return eew.class_lookup['Hawaiian Home Land']
    if LSAD == "79":
        return eew.class_lookup['Alaska Native Village']
    return eew.class_lookup['American Indian Tribal Area']

new_aiannh['instance_of_qid'] = new_aiannh.LSAD.apply(set_instance_of)

# %%
new_aiannh.head()
# Out:
#    AIANNHCE  AIANNHNS       AFFGEOID GEOID                NAME  \
# 0      9515   2418775  2500000US9515  9515      Apache Choctaw
# 1      9370    979494  2500000US9370  9370          Shinnecock
# 2      9820   2418693  2500000US9820  9820  MaChis Lower Creek
# 3      6125   2418774  2500000US6125  6125               Anvik
# 4      6350   2418836  2500000US6350  6350              Circle
#
#                          NAMELSAD LSAD       ALAND   AWATER  \
# 0            Apache Choctaw SDTSA   92   221751364  2632531
# 1  Shinnecock (state) Reservation   86     3494292        0
# 2        MaChis Lower Creek SDTSA   92  1680767035  6816074
# 3                     Anvik ANVSA   79    24578643  6308736
# 4                    Circle ANVSA   79   274634016  1398608
#
#                                             geometry  \
# 0  POLYGON ((-93.77547 31.61936, -93.77411 31.619...
# 1  POLYGON ((-72.44070 40.87749, -72.43870 40.879...
# 2  MULTIPOLYGON (((-85.54654 31.21440, -85.54342 ...
# 3  POLYGON ((-160.24545 62.69478, -160.24517 62.6...
# 4  POLYGON ((-144.38284 65.73496, -144.37907 65.7...
#
#                    coordinates  gnis_id lsad_qid             lsadLabel  \
# 0   POINT (-93.66701 31.62824)  2418775   Q30181        SDTSA (suffix)
# 1   POINT (-72.43098 40.87373)   979494   Q30175  Reservation (suffix)
# 2   POINT (-86.02243 31.33836)  2418693   Q30181        SDTSA (suffix)
# 3  POINT (-160.21395 62.65408)  2418774   Q30168        ANVSA (suffix)
# 4  POINT (-144.18135 65.79338)  2418836   Q30168        ANVSA (suffix)
#
#   instance_of_qid
# 0          Q30257
# 1          Q30257
# 2          Q30257
# 3          Q30256
# 4          Q30256

# %%
for index, row in new_aiannh.iterrows():
    item = eew.wbi.item.new()

    item.labels.set('en', row.NAMELSAD)
    item.aliases.set('en', row.NAME)
    if row.LSAD == '78':
        item.descriptions.set('en', 'a Hawaiian Native Homeland')
    elif row.LSAD == '79':
        item.descriptions.set('en', 'an Alaska Native Village')
    else:
        item.descriptions.set('en', 'an American Indian Tribal area')

    item_claims = eew.models.Claims()

    item_claims.add(
        eew.datatypes.Item(
            prop_nr=eew.prop_lookup['instance of'],
            value=row.instance_of_qid,
            references=references
        )
    )

    item_claims.add(
        eew.datatypes.ExternalID(
            prop_nr=eew.prop_lookup['GNIS ID'],
            value=str(row.AIANNHNS),
            references=references
        )
    )

    item_claims.add(
        eew.datatypes.ExternalID(
            prop_nr=eew.prop_lookup['TIGER GEOID'],
            value=str(row.GEOID),
            references=references
        )
    )

    item_claims.add(
        eew.datatypes.Item(
            prop_nr=eew.prop_lookup['Legal/Statistical Area Description'],
            value=row.lsad_qid,
            references=references
        )
    )

    item_claims.add(
        eew.datatypes.GlobeCoordinate(
            prop_nr=eew.prop_lookup['coordinate location'],
            latitude=row.coordinates.y,
            longitude=row.coordinates.x,
            references=references
        )
    )

    item.claims.add(claims=item_claims)

    try:
        response = item.write(
            summary="Added AIANNH item with information from MPC source"
        )
        print("ADDED:", row.NAMELSAD, response.id)
    except Exception as e:
        print("PROBLEM:", row.NAMELSAD)
# Out:
# ADDED: Apache Choctaw SDTSA Q30258
# ADDED: Shinnecock (state) Reservation Q30259
# ADDED: MaChis Lower Creek SDTSA Q30260
# ADDED: Anvik ANVSA Q30261
# ADDED: Circle ANVSA Q30262
# ADDED: Akhiok ANVSA Q30263
# ADDED: Chevak ANVSA Q30264
# ADDED: Selawik ANVSA Q30265
# ADDED: Ambler ANVSA Q30266
# ADDED: Scammon Bay ANVSA Q30267
# ADDED: Kaohe-Olaa Hawaiian Home Land Q30268
# ADDED: Kickapoo OTSA Q30269
# ADDED: Tetlin ANVSA Q30270
# ADDED: Kaltag ANVSA Q30271
# ADDED: Paukukalo Hawaiian Home Land Q30272
# ADDED: Haliwa-Saponi SDTSA Q30273
# ADDED: Pawnee OTSA Q30274
# ADDED: Choctaw OTSA Q30275
# ADDED: Emmonak ANVSA Q30276
# ADDED: Napaskiak ANVSA Q30277
# ADDED: Nikolski ANVSA Q30278
# ADDED: Rohnerville (Rancheria) Trust Land Q30279
# ADDED: Akiak ANVSA Q30280
# ADDED: St. Paul ANVSA Q30281
# ADDED: Nome ANVSA Q30282
# ADDED: Hydaburg ANVSA Q30283
# ADDED: Chickaloon ANVSA Q30284
# ADDED: Chickasaw OTSA Q30285
# ADDED: Modoc OTSA Q30286
# ADDED: White Mountain ANVSA Q30287
# ADDED: King Cove ANVSA Q30288
# ADDED: Upolu Hawaiian Home Land Q30289
# ADDED: Koyukuk ANVSA Q30290
# ADDED: Pearl City Hawaiian Home Land Q30291
# ADDED: Celilo Village Q30292
# ADDED: Kivalina ANVSA Q30293
# ADDED: Rampart ANVSA Q30294
# ADDED: Tanana ANVSA Q30295
# ADDED: Piihonua Hawaiian Home Land Q30296
# ADDED: Panaewa (Residential) Hawaiian Home Land Q30297
# ADDED: Koyuk ANVSA Q30298
# ADDED: Mechoopda TDSA Q30299
# ADDED: Moloaa Hawaiian Home Land Q30300
# ADDED: Wrangell ANVSA Q30301
# ADDED: Chefornak ANVSA Q30302
# ADDED: Chuathbaluk ANVSA Q30303
# ADDED: Chilkat ANVSA Q30304
# ADDED: Peoria OTSA Q30305
# ADDED: Caddo-Wichita-Delaware OTSA Q30306
# ADDED: Kipnuk ANVSA Q30307
# ADDED: Noatak ANVSA Q30308
# ADDED: Panaewa (Agricultural) Hawaiian Home Land Q30309
# ADDED: Waimanu Hawaiian Home Land Q30310
# ADDED: Port Lions ANVSA Q30311
# ADDED: Pilot Station ANVSA Q30312
# ADDED: Noorvik ANVSA Q30313
# ADDED: Akutan ANVSA Q30314
# ADDED: Nuiqsut ANVSA Q30315
# ADDED: Manokotak ANVSA Q30316
# ADDED: Isle de Jean Charles SDTSA Q30317
# ADDED: San Felipe Pueblo/Santa Ana Pueblo joint-use area Q30318
# ADDED: Newtok ANVSA Q30319
