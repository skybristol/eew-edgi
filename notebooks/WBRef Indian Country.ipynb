# %%
import pandas as pd
from wbmaker import WikibaseConnection
from wikibaseintegrator import models, datatypes

# %%
eew = WikibaseConnection('eew')

# %%
properties = eew.properties()
properties.head()
# Out:
#                                     property              propertyLabel  \
# 0  https://eew-edgi.wikibase.cloud/entity/P1                instance of
# 1  https://eew-edgi.wikibase.cloud/entity/P2                subclass of
# 2  https://eew-edgi.wikibase.cloud/entity/P3  related wikidata property
# 3  https://eew-edgi.wikibase.cloud/entity/P4      related wikidata item
# 4  https://eew-edgi.wikibase.cloud/entity/P5              formatter URL
#
#                             property_type pid        p_type
# 0  http://wikiba.se/ontology#WikibaseItem  P1  WikibaseItem
# 1  http://wikiba.se/ontology#WikibaseItem  P2  WikibaseItem
# 2    http://wikiba.se/ontology#ExternalId  P3    ExternalId
# 3    http://wikiba.se/ontology#ExternalId  P4    ExternalId
# 4        http://wikiba.se/ontology#String  P5        String

# %%
def process_table_source(ds_qid, prov_statement):
    # Get datasource config
    ds_config = eew.datasource(ds_qid, output='dict')
    c = ds_config[ds_qid]
    
    # Retrieve source data
    source_df = eew.get_html_table(c['interface_url'])

    # Pull in property reference
    properties = eew.properties()
    property_lookup = properties.set_index('propertyLabel')['pid'].to_dict()
    property_types = properties.set_index('pid')['p_type'].to_dict()
    
    # Build reference to source by pulling source QID from config dataframe
    refs = models.References()
    refs.add(
        datatypes.Item(
            prop_nr=property_lookup['data source'],
            value=ds_qid
        )
    )
    
    # Iterate through each record in source table
    for index, row in source_df.iterrows():
        # Assume new for right now
        item = eew.wbi.item.new()
        
        item.labels.set('en', row[c['label_prop']])

        if c['description_prop'] is not None:
            desc = row[c['description_prop']]
        else:
            desc = f'an item representing a {c["instance_of_label"]}'
        item.descriptions.set('en', desc)
        
        if c['alias_prop'] is not None:
            item.aliases.set('en', row[c['alias_prop']])
            
        # Add instance of claim
        item.claims.add(
            datatypes.Item(
                prop_nr=property_lookup['instance of'],
                value=c['instance_of_qid'],
                references=refs
            )
        )

        # Add individual claims indicated in the config
        for claim_config in c['claims']:
            claim_property_type = property_types[claim_config['pid']]
            
            if claim_property_type == 'WikibaseItem':
                item.claims.add(
                    datatypes.Item(
                        prop_nr=claim_config['pid'],
                        value=row[claim_config['source_prop']],
                        references=refs
                    )
                )

            elif claim_property_type == 'ExternalId':
                item.claims.add(
                    datatypes.ExternalID(
                        prop_nr=claim_config['pid'],
                        value=row[claim_config['source_prop']],
                        references=refs
                    )
                )
            elif claim_property_type == 'String':
                item.claims.add(
                    datatypes.String(
                        prop_nr=claim_config['pid'],
                        value=row[claim_config['source_prop']],
                        references=refs
                    )
                )
            elif claim_property_type == 'GlobeCoordinate':
                coord_props = claim_config['source_prop'].split(',')
                lat_value = float(row[coord_props[0]])
                lon_value = float(row[coord_props[0]])
                item.claims.add(
                    datatypes.GlobeCoordinate(
                        prop_nr=claim_config['pid'],
                        latitude=lat_value,
                        longitude=lon_value,
                        references=refs
                    )
                )
            elif claim_property_type == 'Url':
                item.claims.add(
                    datatypes.URL(
                        prop_nr=claim_config['pid'],
                        value=row[claim_config['source_prop']],
                        references=refs
                    )
                )
            elif claim_property_type == 'Quantity':
                item.claims.add(
                    datatypes.Quantity(
                        prop_nr=claim_config['pid'],
                        value=row[claim_config['source_prop']],
                        references=refs
                    )
                )

        print(item)
        # item_response = item.write(summary="added new American Indian Reservation item from TIGER source")    
        # print("PROCESSED:", row.NAME, item_response.id)

# %%
process_table_source('Q321', 'Maybe this will work?')
# Out:
# <ItemEntity @371e50 _BaseEntity__api=<wikibaseintegrator.wikibaseintegrator.WikibaseIntegrator object at 0x7f2138371210>
# 	 _BaseEntity__title=None
# 	 _BaseEntity__pageid=None
# 	 _BaseEntity__lastrevid=None
# 	 _BaseEntity__type='item'
# 	 _BaseEntity__id=None
# 	 _BaseEntity__claims=<Claims @37e950 _Claims__claims={'P1': [<Item @37f810 _Claim__mainsnak=<Snak @37e390 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P1' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 323, 'id': 'Q323'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37c350 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P25': [<ExternalID @37d110 _Claim__mainsnak=<Snak @37df10 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P25' _Snak__hash=None _Snak__datavalue={'value': '02419295', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37ed50 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P11': [<GlobeCoordinate @37cb50 _Claim__mainsnak=<Snak @37f090 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P11' _Snak__hash=None _Snak__datavalue={'value': {'latitude': 61.9750493, 'longitude': 61.9750493, 'altitude': None, 'precision': 0.0002777777777777778, 'globe': 'http://www.wikidata.org/entity/Q2'}, 'type': 'globecoordinate'} _Snak__datatype='globe-coordinate'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37e050 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P36': [<ExternalID @41a990 _Claim__mainsnak=<Snak @37ea90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P36' _Snak__hash=None _Snak__datavalue={'value': '0200590', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37d750 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>]}>
# 	 _ItemEntity__labels=<Labels @37f3d0 _LanguageValues__values={'en': <LanguageValue @372290 _LanguageValue__language='en' _LanguageValue__value='Ahtna Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__descriptions=<Descriptions @37ce50 _LanguageValues__values={'en': <LanguageValue @37e910 _LanguageValue__language='en' _LanguageValue__value='an item representing a Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__aliases=<Aliases @498790 _Aliases__aliases={'en': [<Alias @37c050 _LanguageValue__language='en' _LanguageValue__value='Ahtna' _LanguageValue__removed=False>]}>
# 	 _ItemEntity__sitelinks=<Sitelinks @37dc90 sitelinks={}>>
# <ItemEntity @372bd0 _BaseEntity__api=<wikibaseintegrator.wikibaseintegrator.WikibaseIntegrator object at 0x7f2138370ed0>
# 	 _BaseEntity__title=None
# 	 _BaseEntity__pageid=None
# 	 _BaseEntity__lastrevid=None
# 	 _BaseEntity__type='item'
# 	 _BaseEntity__id=None
# 	 _BaseEntity__claims=<Claims @5c27d0 _Claims__claims={'P1': [<Item @371e50 _Claim__mainsnak=<Snak @372290 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P1' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 323, 'id': 'Q323'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @90d990 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P25': [<ExternalID @371210 _Claim__mainsnak=<Snak @a6f990 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P25' _Snak__hash=None _Snak__datavalue={'value': '02419297', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37ce50 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P11': [<GlobeCoordinate @37ff10 _Claim__mainsnak=<Snak @37eb90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P11' _Snak__hash=None _Snak__datavalue={'value': {'latitude': 54.1893362, 'longitude': 54.1893362, 'altitude': None, 'precision': 0.0002777777777777778, 'globe': 'http://www.wikidata.org/entity/Q2'}, 'type': 'globecoordinate'} _Snak__datatype='globe-coordinate'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37ea90 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P36': [<ExternalID @37f3d0 _Claim__mainsnak=<Snak @37e950 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P36' _Snak__hash=None _Snak__datavalue={'value': '0201570', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37f090 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>]}>
# 	 _ItemEntity__labels=<Labels @370950 _LanguageValues__values={'en': <LanguageValue @498790 _LanguageValue__language='en' _LanguageValue__value='Aleut Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__descriptions=<Descriptions @3e5050 _LanguageValues__values={'en': <LanguageValue @41a990 _LanguageValue__language='en' _LanguageValue__value='an item representing a Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__aliases=<Aliases @56e950 _Aliases__aliases={'en': [<Alias @41b050 _LanguageValue__language='en' _LanguageValue__value='Aleut' _LanguageValue__removed=False>]}>
# 	 _ItemEntity__sitelinks=<Sitelinks @486f50 sitelinks={}>>
# <ItemEntity @687990 _BaseEntity__api=<wikibaseintegrator.wikibaseintegrator.WikibaseIntegrator object at 0x7f21399a0090>
# 	 _BaseEntity__title=None
# 	 _BaseEntity__pageid=None
# 	 _BaseEntity__lastrevid=None
# 	 _BaseEntity__type='item'
# 	 _BaseEntity__id=None
# 	 _BaseEntity__claims=<Claims @7f7b90 _Claims__claims={'P1': [<Item @41a990 _Claim__mainsnak=<Snak @498790 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P1' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 323, 'id': 'Q323'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @482150 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P25': [<ExternalID @5c27d0 _Claim__mainsnak=<Snak @486bd0 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P25' _Snak__hash=None _Snak__datavalue={'value': '02419300', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @371210 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P11': [<GlobeCoordinate @a6e490 _Claim__mainsnak=<Snak @370ed0 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P11' _Snak__hash=None _Snak__datavalue={'value': {'latitude': 69.4776597, 'longitude': 69.4776597, 'altitude': None, 'precision': 0.0002777777777777778, 'globe': 'http://www.wikidata.org/entity/Q2'}, 'type': 'globecoordinate'} _Snak__datatype='globe-coordinate'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37e950 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P36': [<ExternalID @37dc90 _Claim__mainsnak=<Snak @37f3d0 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P36' _Snak__hash=None _Snak__datavalue={'value': '0203950', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37eb90 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>]}>
# 	 _ItemEntity__labels=<Labels @907f90 _LanguageValues__values={'en': <LanguageValue @56e950 _LanguageValue__language='en' _LanguageValue__value='Arctic Slope Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__descriptions=<Descriptions @9cc5d0 _LanguageValues__values={'en': <LanguageValue @3e5050 _LanguageValue__language='en' _LanguageValue__value='an item representing a Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__aliases=<Aliases @37f050 _Aliases__aliases={'en': [<Alias @41b050 _LanguageValue__language='en' _LanguageValue__value='Arctic Slope' _LanguageValue__removed=False>]}>
# 	 _ItemEntity__sitelinks=<Sitelinks @37f290 sitelinks={}>>
# <ItemEntity @37fc10 _BaseEntity__api=<wikibaseintegrator.wikibaseintegrator.WikibaseIntegrator object at 0x7f213837f250>
# 	 _BaseEntity__title=None
# 	 _BaseEntity__pageid=None
# 	 _BaseEntity__lastrevid=None
# 	 _BaseEntity__type='item'
# 	 _BaseEntity__id=None
# 	 _BaseEntity__claims=<Claims @37d110 _Claims__claims={'P1': [<Item @907f90 _Claim__mainsnak=<Snak @56e950 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P1' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 323, 'id': 'Q323'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @371210 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P25': [<ExternalID @7f7b90 _Claim__mainsnak=<Snak @370950 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P25' _Snak__hash=None _Snak__datavalue={'value': '02419308', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @482150 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P11': [<GlobeCoordinate @372bd0 _Claim__mainsnak=<Snak @90d990 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P11' _Snak__hash=None _Snak__datavalue={'value': {'latitude': 64.8395097, 'longitude': 64.8395097, 'altitude': None, 'precision': 0.0002777777777777778, 'globe': 'http://www.wikidata.org/entity/Q2'}, 'type': 'globecoordinate'} _Snak__datatype='globe-coordinate'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @a6e490 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P36': [<ExternalID @484210 _Claim__mainsnak=<Snak @486bd0 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P36' _Snak__hash=None _Snak__datavalue={'value': '0206370', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37dc90 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>]}>
# 	 _ItemEntity__labels=<Labels @37e390 _LanguageValues__values={'en': <LanguageValue @687990 _LanguageValue__language='en' _LanguageValue__value='Bering Straits Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__descriptions=<Descriptions @37cb50 _LanguageValues__values={'en': <LanguageValue @9cc5d0 _LanguageValue__language='en' _LanguageValue__value='an item representing a Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__aliases=<Aliases @37e910 _Aliases__aliases={'en': [<Alias @3e5050 _LanguageValue__language='en' _LanguageValue__value='Bering Straits' _LanguageValue__removed=False>]}>
# 	 _ItemEntity__sitelinks=<Sitelinks @37ce50 sitelinks={}>>
# <ItemEntity @37f350 _BaseEntity__api=<wikibaseintegrator.wikibaseintegrator.WikibaseIntegrator object at 0x7f213837c350>
# 	 _BaseEntity__title=None
# 	 _BaseEntity__pageid=None
# 	 _BaseEntity__lastrevid=None
# 	 _BaseEntity__type='item'
# 	 _BaseEntity__id=None
# 	 _BaseEntity__claims=<Claims @37f810 _Claims__claims={'P1': [<Item @90d990 _Claim__mainsnak=<Snak @484210 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P1' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 323, 'id': 'Q323'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @a6f990 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P25': [<ExternalID @486bd0 _Claim__mainsnak=<Snak @482150 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P25' _Snak__hash=None _Snak__datavalue={'value': '02419321', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @56e950 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P11': [<GlobeCoordinate @41b050 _Claim__mainsnak=<Snak @372290 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P11' _Snak__hash=None _Snak__datavalue={'value': {'latitude': 58.829104, 'longitude': 58.829104, 'altitude': None, 'precision': 0.0002777777777777778, 'globe': 'http://www.wikidata.org/entity/Q2'}, 'type': 'globecoordinate'} _Snak__datatype='globe-coordinate'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @371e50 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P36': [<ExternalID @370950 _Claim__mainsnak=<Snak @371210 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P36' _Snak__hash=None _Snak__datavalue={'value': '0209040', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37cb50 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>]}>
# 	 _ItemEntity__labels=<Labels @37ff10 _LanguageValues__values={'en': <LanguageValue @3e5050 _LanguageValue__language='en' _LanguageValue__value='Bristol Bay Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__descriptions=<Descriptions @37e090 _LanguageValues__values={'en': <LanguageValue @9cc5d0 _LanguageValue__language='en' _LanguageValue__value='an item representing a Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__aliases=<Aliases @37e8d0 _Aliases__aliases={'en': [<Alias @687990 _LanguageValue__language='en' _LanguageValue__value='Bristol Bay' _LanguageValue__removed=False>]}>
# 	 _ItemEntity__sitelinks=<Sitelinks @37ed50 sitelinks={}>>
# <ItemEntity @9a0090 _BaseEntity__api=<wikibaseintegrator.wikibaseintegrator.WikibaseIntegrator object at 0x7f213837c050>
# 	 _BaseEntity__title=None
# 	 _BaseEntity__pageid=None
# 	 _BaseEntity__lastrevid=None
# 	 _BaseEntity__type='item'
# 	 _BaseEntity__id=None
# 	 _BaseEntity__claims=<Claims @37f3d0 _Claims__claims={'P1': [<Item @5c27d0 _Claim__mainsnak=<Snak @56e950 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P1' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 323, 'id': 'Q323'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @371210 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P25': [<ExternalID @482150 _Claim__mainsnak=<Snak @372290 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P25' _Snak__hash=None _Snak__datavalue={'value': '02419328', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @a6f990 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P11': [<GlobeCoordinate @41a990 _Claim__mainsnak=<Snak @498790 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P11' _Snak__hash=None _Snak__datavalue={'value': {'latitude': 61.2535907, 'longitude': 61.2535907, 'altitude': None, 'precision': 0.0002777777777777778, 'globe': 'http://www.wikidata.org/entity/Q2'}, 'type': 'globecoordinate'} _Snak__datatype='globe-coordinate'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @486f50 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P36': [<ExternalID @7f7b90 _Claim__mainsnak=<Snak @486bd0 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P36' _Snak__hash=None _Snak__datavalue={'value': '0209800', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37ff10 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>]}>
# 	 _ItemEntity__labels=<Labels @37e310 _LanguageValues__values={'en': <LanguageValue @687990 _LanguageValue__language='en' _LanguageValue__value='Calista Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__descriptions=<Descriptions @37f290 _LanguageValues__values={'en': <LanguageValue @9cc5d0 _LanguageValue__language='en' _LanguageValue__value='an item representing a Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__aliases=<Aliases @37dc90 _Aliases__aliases={'en': [<Alias @41b050 _LanguageValue__language='en' _LanguageValue__value='Calista' _LanguageValue__removed=False>]}>
# 	 _ItemEntity__sitelinks=<Sitelinks @37d750 sitelinks={}>>
# <ItemEntity @37fc10 _BaseEntity__api=<wikibaseintegrator.wikibaseintegrator.WikibaseIntegrator object at 0x7f213837d110>
# 	 _BaseEntity__title=None
# 	 _BaseEntity__pageid=None
# 	 _BaseEntity__lastrevid=None
# 	 _BaseEntity__type='item'
# 	 _BaseEntity__id=None
# 	 _BaseEntity__claims=<Claims @37ce50 _Claims__claims={'P1': [<Item @687990 _Claim__mainsnak=<Snak @7f7b90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P1' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 323, 'id': 'Q323'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @486bd0 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P25': [<ExternalID @41b050 _Claim__mainsnak=<Snak @484210 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P25' _Snak__hash=None _Snak__datavalue={'value': '02419341', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @a6e490 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P11': [<GlobeCoordinate @56e950 _Claim__mainsnak=<Snak @370ed0 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P11' _Snak__hash=None _Snak__datavalue={'value': {'latitude': 60.3971169, 'longitude': 60.3971169, 'altitude': None, 'precision': 0.0002777777777777778, 'globe': 'http://www.wikidata.org/entity/Q2'}, 'type': 'globecoordinate'} _Snak__datatype='globe-coordinate'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @370950 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P36': [<ExternalID @372bd0 _Claim__mainsnak=<Snak @372290 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P36' _Snak__hash=None _Snak__datavalue={'value': '0214410', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37f290 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>]}>
# 	 _ItemEntity__labels=<Labels @37df10 _LanguageValues__values={'en': <LanguageValue @9a0090 _LanguageValue__language='en' _LanguageValue__value='Chugach Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__descriptions=<Descriptions @37e950 _LanguageValues__values={'en': <LanguageValue @9cc5d0 _LanguageValue__language='en' _LanguageValue__value='an item representing a Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__aliases=<Aliases @37ea90 _Aliases__aliases={'en': [<Alias @3e5050 _LanguageValue__language='en' _LanguageValue__value='Chugach' _LanguageValue__removed=False>]}>
# 	 _ItemEntity__sitelinks=<Sitelinks @37f250 sitelinks={}>>
# <ItemEntity @37ed50 _BaseEntity__api=<wikibaseintegrator.wikibaseintegrator.WikibaseIntegrator object at 0x7f213837f050>
# 	 _BaseEntity__title=None
# 	 _BaseEntity__pageid=None
# 	 _BaseEntity__lastrevid=None
# 	 _BaseEntity__type='item'
# 	 _BaseEntity__id=None
# 	 _BaseEntity__claims=<Claims @37cb50 _Claims__claims={'P1': [<Item @56e950 _Claim__mainsnak=<Snak @372bd0 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P1' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 323, 'id': 'Q323'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @371210 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P25': [<ExternalID @372290 _Claim__mainsnak=<Snak @a6e490 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P25' _Snak__hash=None _Snak__datavalue={'value': '02418878', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @7f7b90 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P11': [<GlobeCoordinate @482150 _Claim__mainsnak=<Snak @90d990 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P11' _Snak__hash=None _Snak__datavalue={'value': {'latitude': 61.1203527, 'longitude': 61.1203527, 'altitude': None, 'precision': 0.0002777777777777778, 'globe': 'http://www.wikidata.org/entity/Q2'}, 'type': 'globecoordinate'} _Snak__datatype='globe-coordinate'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @41b050 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P36': [<ExternalID @484210 _Claim__mainsnak=<Snak @486bd0 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P36' _Snak__hash=None _Snak__datavalue={'value': '0217140', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37e950 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>]}>
# 	 _ItemEntity__labels=<Labels @37eb90 _LanguageValues__values={'en': <LanguageValue @3e5050 _LanguageValue__language='en' _LanguageValue__value='Cook Inlet Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__descriptions=<Descriptions @37e8d0 _LanguageValues__values={'en': <LanguageValue @9cc5d0 _LanguageValue__language='en' _LanguageValue__value='an item representing a Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__aliases=<Aliases @37f090 _Aliases__aliases={'en': [<Alias @9a0090 _LanguageValue__language='en' _LanguageValue__value='Cook Inlet' _LanguageValue__removed=False>]}>
# 	 _ItemEntity__sitelinks=<Sitelinks @37e390 sitelinks={}>>
# <ItemEntity @907f90 _BaseEntity__api=<wikibaseintegrator.wikibaseintegrator.WikibaseIntegrator object at 0x7f213837c350>
# 	 _BaseEntity__title=None
# 	 _BaseEntity__pageid=None
# 	 _BaseEntity__lastrevid=None
# 	 _BaseEntity__type='item'
# 	 _BaseEntity__id=None
# 	 _BaseEntity__claims=<Claims @37f3d0 _Claims__claims={'P1': [<Item @482150 _Claim__mainsnak=<Snak @90d990 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P1' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 323, 'id': 'Q323'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @41b050 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P25': [<ExternalID @484210 _Claim__mainsnak=<Snak @7f7b90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P25' _Snak__hash=None _Snak__datavalue={'value': '02418929', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @56e950 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P11': [<GlobeCoordinate @a6f990 _Claim__mainsnak=<Snak @5c27d0 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P11' _Snak__hash=None _Snak__datavalue={'value': {'latitude': 65.2202261, 'longitude': 65.2202261, 'altitude': None, 'precision': 0.0002777777777777778, 'globe': 'http://www.wikidata.org/entity/Q2'}, 'type': 'globecoordinate'} _Snak__datatype='globe-coordinate'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @371e50 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P36': [<ExternalID @371210 _Claim__mainsnak=<Snak @372bd0 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P36' _Snak__hash=None _Snak__datavalue={'value': '0220010', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37e8d0 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>]}>
# 	 _ItemEntity__labels=<Labels @37e910 _LanguageValues__values={'en': <LanguageValue @9a0090 _LanguageValue__language='en' _LanguageValue__value='Doyon Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__descriptions=<Descriptions @37d750 _LanguageValues__values={'en': <LanguageValue @9cc5d0 _LanguageValue__language='en' _LanguageValue__value='an item representing a Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__aliases=<Aliases @37c050 _Aliases__aliases={'en': [<Alias @3e5050 _LanguageValue__language='en' _LanguageValue__value='Doyon' _LanguageValue__removed=False>]}>
# 	 _ItemEntity__sitelinks=<Sitelinks @37f350 sitelinks={}>>
# <ItemEntity @37fc10 _BaseEntity__api=<wikibaseintegrator.wikibaseintegrator.WikibaseIntegrator object at 0x7f213837e090>
# 	 _BaseEntity__title=None
# 	 _BaseEntity__pageid=None
# 	 _BaseEntity__lastrevid=None
# 	 _BaseEntity__type='item'
# 	 _BaseEntity__id=None
# 	 _BaseEntity__claims=<Claims @37ce50 _Claims__claims={'P1': [<Item @9a0090 _Claim__mainsnak=<Snak @a6f990 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P1' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 323, 'id': 'Q323'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @498790 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P25': [<ExternalID @5c27d0 _Claim__mainsnak=<Snak @372bd0 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P25' _Snak__hash=None _Snak__datavalue={'value': '02418991', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @372290 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P11': [<GlobeCoordinate @a6e490 _Claim__mainsnak=<Snak @687990 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P11' _Snak__hash=None _Snak__datavalue={'value': {'latitude': 57.3605194, 'longitude': 57.3605194, 'altitude': None, 'precision': 0.0002777777777777778, 'globe': 'http://www.wikidata.org/entity/Q2'}, 'type': 'globecoordinate'} _Snak__datatype='globe-coordinate'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @484210 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P36': [<ExternalID @90d990 _Claim__mainsnak=<Snak @41b050 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P36' _Snak__hash=None _Snak__datavalue={'value': '0241640', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37d750 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>]}>
# 	 _ItemEntity__labels=<Labels @37f810 _LanguageValues__values={'en': <LanguageValue @907f90 _LanguageValue__language='en' _LanguageValue__value='Koniag Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__descriptions=<Descriptions @37f250 _LanguageValues__values={'en': <LanguageValue @3e5050 _LanguageValue__language='en' _LanguageValue__value='an item representing a Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__aliases=<Aliases @37ff10 _Aliases__aliases={'en': [<Alias @9cc5d0 _LanguageValue__language='en' _LanguageValue__value='Koniag' _LanguageValue__removed=False>]}>
# 	 _ItemEntity__sitelinks=<Sitelinks @37d110 sitelinks={}>>
# <ItemEntity @37ed50 _BaseEntity__api=<wikibaseintegrator.wikibaseintegrator.WikibaseIntegrator object at 0x7f213837dc90>
# 	 _BaseEntity__title=None
# 	 _BaseEntity__pageid=None
# 	 _BaseEntity__lastrevid=None
# 	 _BaseEntity__type='item'
# 	 _BaseEntity__id=None
# 	 _BaseEntity__claims=<Claims @37cb50 _Claims__claims={'P1': [<Item @90d990 _Claim__mainsnak=<Snak @687990 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P1' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 323, 'id': 'Q323'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @486f50 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P25': [<ExternalID @41b050 _Claim__mainsnak=<Snak @482150 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P25' _Snak__hash=None _Snak__datavalue={'value': '02419029', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @a6f990 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P11': [<GlobeCoordinate @371e50 _Claim__mainsnak=<Snak @370ed0 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P11' _Snak__hash=None _Snak__datavalue={'value': {'latitude': 67.007823, 'longitude': 67.007823, 'altitude': None, 'precision': 0.0002777777777777778, 'globe': 'http://www.wikidata.org/entity/Q2'}, 'type': 'globecoordinate'} _Snak__datatype='globe-coordinate'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @371210 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P36': [<ExternalID @372290 _Claim__mainsnak=<Snak @372bd0 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P36' _Snak__hash=None _Snak__datavalue={'value': '0252120', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37f250 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>]}>
# 	 _ItemEntity__labels=<Labels @37e310 _LanguageValues__values={'en': <LanguageValue @9cc5d0 _LanguageValue__language='en' _LanguageValue__value='NANA Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__descriptions=<Descriptions @37e390 _LanguageValues__values={'en': <LanguageValue @3e5050 _LanguageValue__language='en' _LanguageValue__value='an item representing a Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__aliases=<Aliases @37f290 _Aliases__aliases={'en': [<Alias @907f90 _LanguageValue__language='en' _LanguageValue__value='NANA' _LanguageValue__removed=False>]}>
# 	 _ItemEntity__sitelinks=<Sitelinks @37f050 sitelinks={}>>
# <ItemEntity @486bd0 _BaseEntity__api=<wikibaseintegrator.wikibaseintegrator.WikibaseIntegrator object at 0x7f213837ea90>
# 	 _BaseEntity__title=None
# 	 _BaseEntity__pageid=None
# 	 _BaseEntity__lastrevid=None
# 	 _BaseEntity__type='item'
# 	 _BaseEntity__id=None
# 	 _BaseEntity__claims=<Claims @37f3d0 _Claims__claims={'P1': [<Item @372290 _Claim__mainsnak=<Snak @372bd0 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P1' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 323, 'id': 'Q323'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @370950 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P25': [<ExternalID @371e50 _Claim__mainsnak=<Snak @482150 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P25' _Snak__hash=None _Snak__datavalue={'value': '02419136', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @90d990 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P11': [<GlobeCoordinate @9a0090 _Claim__mainsnak=<Snak @498790 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P11' _Snak__hash=None _Snak__datavalue={'value': {'latitude': 57.2934294, 'longitude': 57.2934294, 'altitude': None, 'precision': 0.0002777777777777778, 'globe': 'http://www.wikidata.org/entity/Q2'}, 'type': 'globecoordinate'} _Snak__datatype='globe-coordinate'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @41b050 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>], 'P36': [<ExternalID @486f50 _Claim__mainsnak=<Snak @484210 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P36' _Snak__hash=None _Snak__datavalue={'value': '0267940', 'type': 'string'} _Snak__datatype='external-id'> _Claim__type='statement' _Claim__qualifiers=<Qualifiers @37e390 _Qualifiers__qualifiers={}> _Claim__qualifiers_order=[] _Claim__id=None _Claim__rank=<WikibaseRank.NORMAL: 'normal'> _Claim__removed=False _Claim__references=<References @4826d0 _References__references=[<Reference @373ad0 _Reference__hash=None _Reference__snaks=<Snaks @48cb50 snaks={'P6': [<Snak @49ae90 _Snak__snaktype=<WikibaseSnakType.KNOWN_VALUE: 'value'> _Snak__property_number='P6' _Snak__hash=None _Snak__datavalue={'value': {'entity-type': 'item', 'numeric-id': 321, 'id': 'Q321'}, 'type': 'wikibase-entityid'} _Snak__datatype='wikibase-item'>]}> _Reference__snaks_order=[]>]>>]}>
# 	 _ItemEntity__labels=<Labels @37df10 _LanguageValues__values={'en': <LanguageValue @907f90 _LanguageValue__language='en' _LanguageValue__value='Sealaska Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__descriptions=<Descriptions @37f350 _LanguageValues__values={'en': <LanguageValue @3e5050 _LanguageValue__language='en' _LanguageValue__value='an item representing a Alaska Native Regional Corporation' _LanguageValue__removed=False>}>
# 	 _ItemEntity__aliases=<Aliases @37e950 _Aliases__aliases={'en': [<Alias @9cc5d0 _LanguageValue__language='en' _LanguageValue__value='Sealaska' _LanguageValue__removed=False>]}>
# 	 _ItemEntity__sitelinks=<Sitelinks @37c350 sitelinks={}>>

# %% [markdown]
# # Alaska Native Regional Corporations

# %%
ds_qid = 'Q321'
ds_wb_source = eew.datasource(ds_qid, output='dict')
ds_wb_source
# Out:
# {'Q321': {'label_prop': 'NAME',
#   'description_prop': None,
#   'alias_prop': 'BASENAME',
#   'claims': [{'pid': 'P25', 'label': 'GNIS ID', 'source_prop': 'ANRCNS'},
#    {'pid': 'P11',
#     'label': 'coordinate location',
#     'source_prop': 'CENTLAT,CENTLON'},
#    {'pid': 'P36', 'label': 'TIGER GEOID', 'source_prop': 'GEOID'}],
#   'interface_type': 'html table',
#   'interface_url': 'https://tigerweb.geo.census.gov/tigerwebmain/Files/bas23/tigerweb_bas23_anrc_us.html',
#   'instance_of_qid': 'Q323',
#   'instance_of_label': 'Alaska Native Regional Corporation'}}

# %%
anrc_data = eew.get_html_table(url=anrc_data_source['html_table'])

# %%
# refs = models.References()
# refs.add(
#     datatypes.Item(
#         prop_nr='P6',
#         value='Q321'
#     )
# )

# for index, row in anrc_data.iterrows():
#     item = eew.wbi.item.new()
#     item.labels.set('en', row.NAME)
#     item.descriptions.set('en', 'an Alaska Native Regional Corporation identified in TIGER source data')
#     item.aliases.set('en', row.BASENAME)

#     item.claims.add(
#         datatypes.Item(
#             prop_nr='P1',
#             value='Q323',
#             references=refs
#         )
#     )

#     item.claims.add(
#         datatypes.ExternalID(
#             prop_nr='P25',
#             value=row.ANRCNS.lstrip('0'),
#             references=refs
#         )
#     )

#     item.claims.add(
#         datatypes.ExternalID(
#             prop_nr='P36',
#             value=row.GEOID,
#             references=refs
#         )
#     )

#     item.claims.add(
#         datatypes.GlobeCoordinate(
#             prop_nr='P11',
#             latitude=float(row.CENTLAT),
#             longitude=float(row.CENTLON),
#             references=refs
#         )
#     )

#     item_response = item.write(summary="added new ANRC item from TIGER source")    
#     print("PROCESSED:", row.NAME, item_response.id)

# %% [markdown]
# # Federal American Indian Reservations

# %%
indian_res_source_qid = 'Q337'
indian_res_source = datasources[indian_res_source_qid]
indian_res_data = eew.get_html_table(url=indian_res_source['html_table'])

# %%
indian_res_data.head()

# %%
refs = models.References()
refs.add(
    datatypes.Item(
        prop_nr=properties['data source'],
        value=indian_res_source_qid
    )
)

for index, row in indian_res_data.iterrows():
    item = eew.wbi.item.new()
    item.labels.set('en', row.NAME)
    item.descriptions.set('en', 'a Federal American Indian Reservation identified in TIGER source data')
    item.aliases.set('en', row.BASENAME)

    item.claims.add(
        datatypes.Item(
            prop_nr=properties['instance of'],
            value=indian_res_source['entity_classifier'].split('/')[-1],
            references=refs
        )
    )

    item.claims.add(
        datatypes.ExternalID(
            prop_nr=properties['GNIS ID'],
            value=row.AIANNHNS.lstrip('0'),
            references=refs
        )
    )

    item.claims.add(
        datatypes.ExternalID(
            prop_nr=properties['TIGER GEOID'],
            value=row.GEOID,
            references=refs
        )
    )

    item.claims.add(
        datatypes.GlobeCoordinate(
            prop_nr=properties['coordinate location'],
            latitude=float(row.CENTLAT),
            longitude=float(row.CENTLON),
            references=refs
        )
    )

    item_response = item.write(summary="added new American Indian Reservation item from TIGER source")    
    print("PROCESSED:", row.NAME, item_response.id)

# %% [markdown]
# # Hawaiian Home Lands

# %%
hawaiian_home_land_source_id = 'Q522'
hawaiian_home_land_config = html_table_datasources[hawaiian_home_land_source_id]
hawaiian_home_land_config

# %%
hawaiian_home_land_data = eew.get_html_table(url=hawaiian_home_land_config['source_url'])
hawaiian_home_land_data.head()

# %%
model = datatypes.Item()

# %%
item = eew.wbi.item.get('Q522')

# %%
item.get_json()
