# %% [markdown]
# # Standard Industry Classification

# %% [markdown]
# The U.S. Securities and Exchange Commission maintains a classification for the industries it regulates. The Standard Industry Classification codes are one of the reference elements in the U.S. EPA's Facility Registration System. To help connect the dots between information sources, we build the SIC codes and names as a reference within the knowledgebase. When we process facility records, we link to these entities as classification items on facilities.

# %%
import os
import pandas as pd

from wikibaseintegrator.wbi_config import config as wbi_config
from wikibaseintegrator import WikibaseIntegrator, wbi_login
from wikibaseintegrator.models import Qualifiers, References, Reference
from wikibaseintegrator import datatypes
from wikibaseintegrator.wbi_helpers import execute_sparql_query

# %%
wbi_config['MEDIAWIKI_API_URL'] = os.environ['MEDIAWIKI_API_URL']
wbi_config['SPARQL_ENDPOINT_URL'] = os.environ['SPARQL_ENDPOINT_URL']
wbi_config['WIKIBASE_URL'] = os.environ['WIKIBASE_URL']
wbi_config['USER_AGENT'] = f'EDJIBot/1.0 ({os.environ["WIKIBASE_URL"]})'

login_instance = wbi_login.Login(
    user=os.environ['BOT_NAME'],
    password=os.environ['BOT_PASS']
)

wbi = WikibaseIntegrator(login=login_instance)

# %% [markdown]
# ## EDJI-KB properties, classification, and data sources

# %% [markdown]
# We set up the knowledgebase with a set of properties to be used in characterizing items with information, a set of organizing classes (subclasses below entity) that are used in instance of classification of items, and a set of data sources that serve to document specifics about provenance. We pull these into the notebook here so that we can reference them by name and get their associated QID values for the particular Wikibase instance we are operating on.

# %%
prop_query = """
SELECT ?property ?propertyLabel WHERE {
  # ?property a wikibase:Property .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
"""

edjikb_props = execute_sparql_query(prop_query)
edjikb_prop_lookup = {}
for x in edjikb_props['results']['bindings']:
    edjikb_prop_lookup[x['propertyLabel']['value']] = x['property']['value'].split('/')[-1]

display(edjikb_prop_lookup)

class_query = """
PREFIX wdt: <https://edji-knows.wikibase.cloud/prop/direct/>

SELECT ?class ?classLabel WHERE {
  # ?class wdt:P2 [] .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
"""

edjikb_classes = execute_sparql_query(class_query)
edjikb_class_lookup = {}
for x in edjikb_classes['results']['bindings']:
    edjikb_class_lookup[x['classLabel']['value']] = x['class']['value'].split('/')[-1]

display(edjikb_class_lookup)

datasource_query = """
PREFIX wd: <https://edji-knows.wikibase.cloud/entity/>
PREFIX wdt: <https://edji-knows.wikibase.cloud/prop/direct/>

SELECT ?ds ?dsLabel WHERE {
  # ?ds wdt:P1 wd:Q4 .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
"""

edjikb_datasources = execute_sparql_query(datasource_query)
edjikb_datasource_lookup = {}
for x in edjikb_datasources['results']['bindings']:
    edjikb_datasource_lookup[x['dsLabel']['value']] = x['ds']['value'].split('/')[-1]

display(edjikb_datasource_lookup)
# Out:
# {'instance of': 'P1',
#  'subclass of': 'P2',
#  'SIC Code': 'P3',
#  'reference url': 'P4',
#  'data source': 'P5'}
# {'spatio-temporal activity': 'Q2',
#  'data source': 'Q4',
#  'industrial activity': 'Q3'}
# {'SEC listing of SIC codes': 'Q5'}

# %% [markdown]
# ### SIC Source

# %% [markdown]
# The source item in the knowledgebase describes a web page with a table listing the SIC codes. This is the best source I've found for this information that appears to be comprehensive, current, and authoritative. It's a simple enough thing that we can simply read the page using Pandas' read_html method to get the table as a dataframe for processing. It's crude but effective enough.

# %% [markdown]
# Note: I need to do more work on the data source idea in the Wikibase design to better describe something about the type of process run against a source. We can also point to the code used to introduce the items.

# %%
sec_sic_page = pd.read_html("https://www.sec.gov/corpfin/division-of-corporation-finance-standard-industrial-classification-sic-code-list")
sec_sic_page[0]
# Out:
#      SIC Code                                Office  \
# 0         100  Industrial Applications and Services
# 1         200  Industrial Applications and Services
# 2         700  Industrial Applications and Services
# 3         800  Industrial Applications and Services
# 4         900  Industrial Applications and Services
# ..        ...                                   ...
# 439      8880      Office of International Corp Fin
# 440      8888      Office of International Corp Fin
# 441      8900            Office of Trade & Services
# 442      9721      Office of International Corp Fin
# 443      9995  Office of Real Estate & Construction
#
#                                        Industry Title
# 0                       AGRICULTURAL PRODUCTION-CROPS
# 1    AGRICULTURAL PROD-LIVESTOCK & ANIMAL SPECIALTIES
# 2                               AGRICULTURAL SERVICES
# 3                                            FORESTRY
# 4                       FISHING, HUNTING AND TRAPPING
# ..                                                ...
# 439                      AMERICAN DEPOSITARY RECEIPTS
# 440                               FOREIGN GOVERNMENTS
# 441                            SERVICES-SERVICES, NEC
# 442                             INTERNATIONAL AFFAIRS
# 443                      NON-OPERATING ESTABLISHMENTS
#
# [444 rows x 3 columns]

# %% [markdown]
# ### Item Processing

# %% [markdown]
# For a few hundred items, this basic serial looping process is fine. I don't really understand the "fast run mode" for the WikibaseIntegrator package, and I'm not sure it would be all that effective anyway. Nominally, I could parallelize this by packaging up the WBI item construct and then chunking out runners that instantiate the WBI connection and send the data. But I don't know how much the Wikibase API can handle at once anyway and if there might be a better way to handle the connections. I need to research further.

# %%
sic_refs = References()
sic_ref = Reference()
sic_ref.add(
    datatypes.Item(
        prop_nr=edjikb_prop_lookup['data source'],
        value=edjikb_datasource_lookup['SEC listing of SIC codes']
    )
)
sic_refs.add(sic_ref)

for index, row in sec_sic_page[0].iterrows():
    print("PROCESSING:", row['Industry Title'])
    
    item = wbi.item.new()
    
    item.labels.set('en', row['Industry Title'].strip())
    item.descriptions.set('en', 'a Standard Industry Classification type of industry')

    instance_of_claim = Item(
        prop_nr=edjikb_prop_lookup['instance of'],
        value=edjikb_class_lookup['industrial activity'],
        references=sic_refs
    )
    item.claims.add(instance_of_claim)

    sic_code_claim = ExternalID(
        prop_nr=edjikb_prop_lookup['SIC Code'],
        value=str(row['SIC Code']),
        references=sic_refs
    )
    item.claims.add(sic_code_claim)

    item.write()
# Out:
# PROCESSING: AGRICULTURAL PRODUCTION-CROPS
# PROCESSING: AGRICULTURAL PROD-LIVESTOCK & ANIMAL SPECIALTIES
# PROCESSING: AGRICULTURAL SERVICES
# PROCESSING: FORESTRY
# PROCESSING: FISHING, HUNTING AND TRAPPING
# PROCESSING: METAL MINING
# PROCESSING: GOLD AND SILVER ORES
# PROCESSING: MISCELLANEOUS METAL ORES
# PROCESSING: BITUMINOUS COAL & LIGNITE MINING
# PROCESSING: BITUMINOUS COAL & LIGNITE SURFACE MINING
# PROCESSING: CRUDE PETROLEUM & NATURAL GAS
# PROCESSING: DRILLING OIL & GAS WELLS
# PROCESSING: OIL & GAS FIELD EXPLORATION SERVICES
# PROCESSING: OIL & GAS FIELD SERVICES, NEC
# PROCESSING: MINING & QUARRYING OF NONMETALLIC MINERALS (NO FUELS)
# PROCESSING: GENERAL BLDG CONTRACTORS - RESIDENTIAL BLDGS
# PROCESSING: OPERATIVE BUILDERS
# PROCESSING: GENERAL BLDG CONTRACTORS - NONRESIDENTIAL BLDGS
# PROCESSING: HEAVY CONSTRUCTION OTHER THAN BLDG CONST - CONTRACTORS
# PROCESSING: WATER, SEWER, PIPELINE, COMM & POWER LINE CONSTRUCTION
# PROCESSING: CONSTRUCTION - SPECIAL TRADE CONTRACTORS
# PROCESSING: ELECTRICAL WORK
# PROCESSING: FOOD AND KINDRED PRODUCTS
# PROCESSING: MEAT PACKING PLANTS
# PROCESSING: SAUSAGES & OTHER PREPARED MEAT PRODUCTS
# PROCESSING: POULTRY SLAUGHTERING AND PROCESSING
# PROCESSING: DAIRY PRODUCTS
# PROCESSING: ICE CREAM & FROZEN DESSERTS
# PROCESSING: CANNED, FROZEN & PRESERVD FRUIT, VEG & FOOD SPECIALTIES
# Service unavailable (HTTP Code 502). Sleeping for 60 seconds.
# PROCESSING: CANNED, FRUITS, VEG, PRESERVES, JAMS & JELLIES
# PROCESSING: GRAIN MILL PRODUCTS
# PROCESSING: BAKERY PRODUCTS
# PROCESSING: COOKIES & CRACKERS
# PROCESSING: SUGAR & CONFECTIONERY PRODUCTS
# PROCESSING: FATS & OILS
# PROCESSING: BEVERAGES
# PROCESSING: MALT BEVERAGES
# PROCESSING: BOTTLED & CANNED SOFT DRINKS & CARBONATED WATERS
# PROCESSING: MISCELLANEOUS FOOD PREPARATIONS & KINDRED PRODUCTS
# PROCESSING: PREPARED FRESH OR FROZEN FISH & SEAFOODS
# PROCESSING: TOBACCO PRODUCTS
# PROCESSING: CIGARETTES
# PROCESSING: TEXTILE MILL PRODUCTS
# PROCESSING: BROADWOVEN FABRIC MILLS, COTTON
# PROCESSING: BROADWOVEN FABRIC MILLS, MAN MADE FIBER & SILK
# PROCESSING: KNITTING MILLS
# PROCESSING: KNIT OUTERWEAR MILLS
# PROCESSING: CARPETS & RUGS
# PROCESSING: APPAREL & OTHER FINISHD PRODS OF FABRICS & SIMILAR MATL
# PROCESSING: MEN'S & BOYS' FURNISHGS, WORK CLOTHG, & ALLIED GARMENTS
# PROCESSING: WOMEN'S, MISSES', AND JUNIORS OUTERWEAR
# PROCESSING: WOMEN'S, MISSES', CHILDREN'S & INFANTS' UNDERGARMENTS
# PROCESSING: MISCELLANEOUS FABRICATED TEXTILE PRODUCTS
# PROCESSING: LUMBER & WOOD PRODUCTS (NO FURNITURE)
# PROCESSING: SAWMILLS & PLANTING MILLS, GENERAL
# PROCESSING: MILLWOOD, VENEER, PLYWOOD, & STRUCTURAL WOOD MEMBERS
# Service unavailable (HTTP Code 502). Sleeping for 60 seconds.
# PROCESSING: MOBILE HOMES
# PROCESSING: PREFABRICATED WOOD BLDGS & COMPONENTS
# PROCESSING: HOUSEHOLD FURNITURE
# PROCESSING: WOOD HOUSEHOLD FURNITURE, (NO UPHOLSTERED)
# PROCESSING: OFFICE FURNITURE
# PROCESSING: OFFICE FURNITURE (NO WOOD)
# PROCESSING: PUBLIC BLDG & RELATED FURNITURE
# PROCESSING: PARTITIONS, SHELVG, LOCKERS, & OFFICE & STORE FIXTURES
# PROCESSING: MISCELLANEOUS FURNITURE & FIXTURES
# PROCESSING: PAPERS & ALLIED PRODUCTS
# PROCESSING: PULP MILLS
# PROCESSING: PAPER MILLS
# PROCESSING: PAPERBOARD MILLS
# PROCESSING: PAPERBOARD CONTAINERS & BOXES
# PROCESSING: CONVERTED PAPER & PAPERBOARD PRODS (NO CONTANERS/BOXES)
# PROCESSING: PLASTICS, FOIL & COATED PAPER BAGS
# PROCESSING: NEWSPAPERS: PUBLISHING OR PUBLISHING & PRINTING
# PROCESSING: PERIODICALS: PUBLISHING OR PUBLISHING & PRINTING
# PROCESSING: BOOKS: PUBLISHING OR PUBLISHING & PRINTING
# PROCESSING: BOOK PRINTING
# PROCESSING: MISCELLANEOUS PUBLISHING
# PROCESSING: COMMERCIAL PRINTING
# PROCESSING: MANIFOLD BUSINESS FORMS
# PROCESSING: GREETING CARDS
# PROCESSING: BLANKBOOKS, LOOSELEAF BINDERS & BOOKBINDG & RELATD WORK
# PROCESSING: SERVICE INDUSTRIES FOR THE PRINTING TRADE
# PROCESSING: CHEMICALS & ALLIED PRODUCTS
# PROCESSING: INDUSTRIAL INORGANIC CHEMICALS
# PROCESSING: PLASTIC MATERIAL, SYNTH RESIN/RUBBER, CELLULOS (NO GLASS)
# PROCESSING: PLASTIC MATERIALS, SYNTH RESINS & NONVULCAN ELASTOMERS
# PROCESSING: MEDICINAL CHEMICALS & BOTANICAL PRODUCTS
# PROCESSING: PHARMACEUTICAL PREPARATIONS
# PROCESSING: IN VITRO & IN VIVO DIAGNOSTIC SUBSTANCES
# PROCESSING: BIOLOGICAL PRODUCTS, (NO DISGNOSTIC SUBSTANCES)
# PROCESSING: SOAP, DETERGENTS, CLEANG PREPARATIONS, PERFUMES, COSMETICS
# PROCESSING: SPECIALTY CLEANING, POLISHING AND SANITATION PREPARATIONS
# PROCESSING: PERFUMES, COSMETICS & OTHER TOILET PREPARATIONS
# PROCESSING: PAINTS, VARNISHES, LACQUERS, ENAMELS & ALLIED PRODS
# PROCESSING: INDUSTRIAL ORGANIC CHEMICALS
# PROCESSING: AGRICULTURAL CHEMICALS
# PROCESSING: MISCELLANEOUS CHEMICAL PRODUCTS
# PROCESSING: ADHESIVES & SEALANTS
# PROCESSING: PETROLEUM REFINING
# PROCESSING: ASPHALT PAVING & ROOFING MATERIALS
# PROCESSING: MISCELLANEOUS PRODUCTS OF PETROLEUM & COAL
# PROCESSING: TIRES & INNER TUBES
# PROCESSING: RUBBER & PLASTICS FOOTWEAR
# PROCESSING: GASKETS, PACKG & SEALG DEVICES & RUBBER & PLASTICS HOSE
# PROCESSING: FABRICATED RUBBER PRODUCTS, NEC
# PROCESSING: MISCELLANEOUS PLASTICS PRODUCTS
# PROCESSING: UNSUPPORTED PLASTICS FILM & SHEET
# PROCESSING: PLASTICS FOAM PRODUCTS
# PROCESSING: PLASTICS PRODUCTS, NEC
# PROCESSING: LEATHER & LEATHER PRODUCTS
# PROCESSING: FOOTWEAR, (NO RUBBER)
# PROCESSING: FLAT GLASS
# PROCESSING: GLASS & GLASSWARE, PRESSED OR BLOWN
# PROCESSING: GLASS CONTAINERS
# PROCESSING: GLASS PRODUCTS, MADE OF PURCHASED GLASS
# PROCESSING: CEMENT, HYDRAULIC
# PROCESSING: STRUCTURAL CLAY PRODUCTS
# PROCESSING: POTTERY & RELATED PRODUCTS
# PROCESSING: CONCRETE, GYPSUM & PLASTER PRODUCTS
# PROCESSING: CONCRETE PRODUCTS, EXCEPT BLOCK & BRICK
# PROCESSING: CUT STONE & STONE PRODUCTS
# PROCESSING: ABRASIVE, ASBESTOS & MISC NONMETALLIC MINERAL PRODS
# PROCESSING: STEEL WORKS, BLAST FURNACES & ROLLING & FINISHING MILLS
# PROCESSING: STEEL WORKS, BLAST FURNACES & ROLLING MILLS (COKE OVENS)
# PROCESSING: STEEL PIPE & TUBES
# PROCESSING: IRON & STEEL FOUNDRIES
# PROCESSING: PRIMARY SMELTING & REFINING OF NONFERROUS METALS
# PROCESSING: PRIMARY PRODUCTION OF ALUMINUM
# PROCESSING: SECONDARY SMELTING & REFINING OF NONFERROUS METALS
# PROCESSING: ROLLING DRAWING & EXTRUDING OF NONFERROUS METALS
# PROCESSING: DRAWING & INSULATING OF NONFERROUS WIRE
# PROCESSING: NONFERROUS FOUNDRIES (CASTINGS)
# PROCESSING: MISCELLANEOUS PRIMARY METAL PRODUCTS
# PROCESSING: METAL CANS
# PROCESSING: METAL SHIPPING BARRELS, DRUMS, KEGS & PAILS
# PROCESSING: CUTLERY, HANDTOOLS & GENERAL HARDWARE
# PROCESSING: HEATING EQUIP, EXCEPT ELEC & WARM AIR; & PLUMBING FIXTURES
# PROCESSING: HEATING EQUIPMENT, EXCEPT ELECTRIC & WARM AIR FURNACES
# PROCESSING: FABRICATED STRUCTURAL METAL PRODUCTS
# PROCESSING: METAL DOORS, SASH, FRAMES, MOLDINGS & TRIM
# PROCESSING: FABRICATED PLATE WORK (BOILER SHOPS)
# PROCESSING: SHEET METAL WORK
# PROCESSING: PREFABRICATED METAL BUILDINGS & COMPONENTS
# PROCESSING: SCREW MACHINE PRODUCTS
# PROCESSING: BOLTS, NUTS, SCREWS, RIVETS & WASHERS
# PROCESSING: METAL FORGINGS & STAMPINGS
# PROCESSING: COATING, ENGRAVING & ALLIED SERVICES
# PROCESSING: ORDNANCE & ACCESSORIES, (NO VEHICLES/GUIDED MISSILES)
# PROCESSING: MISCELLANEOUS FABRICATED METAL PRODUCTS
# PROCESSING: ENGINES & TURBINES
# PROCESSING: FARM MACHINERY & EQUIPMENT
# PROCESSING: LAWN & GARDEN TRACTORS & HOME LAWN & GARDENS EQUIP
# PROCESSING: CONSTRUCTION, MINING & MATERIALS HANDLING MACHINERY & EQUIP
# PROCESSING: CONSTRUCTION MACHINERY & EQUIP
# PROCESSING: MINING MACHINERY & EQUIP (NO OIL & GAS FIELD MACH & EQUIP)
# PROCESSING: OIL & GAS FIELD MACHINERY & EQUIPMENT
# PROCESSING: INDUSTRIAL TRUCKS, TRACTORS, TRAILORS & STACKERS
# PROCESSING: METALWORKG MACHINERY & EQUIPMENT
# PROCESSING: MACHINE TOOLS, METAL CUTTING TYPES
# PROCESSING: SPECIAL INDUSTRY MACHINERY (NO METALWORKING MACHINERY)
# PROCESSING: PRINTING TRADES MACHINERY & EQUIPMENT
# PROCESSING: SPECIAL INDUSTRY MACHINERY, NEC
# PROCESSING: GENERAL INDUSTRIAL MACHINERY & EQUIPMENT
# PROCESSING: PUMPS & PUMPING EQUIPMENT
# PROCESSING: BALL & ROLLER BEARINGS
# PROCESSING: INDUSTRIAL & COMMERCIAL FANS & BLOWERS & AIR PURIFING EQUIP
# PROCESSING: INDUSTRIAL PROCESS FURNACES & OVENS
# PROCESSING: GENERAL INDUSTRIAL MACHINERY & EQUIPMENT, NEC
# PROCESSING: COMPUTER & OFFICE EQUIPMENT
# PROCESSING: ELECTRONIC COMPUTERS
# PROCESSING: COMPUTER STORAGE DEVICES
# PROCESSING: COMPUTER TERMINALS
# PROCESSING: COMPUTER COMMUNICATIONS EQUIPMENT
# PROCESSING: COMPUTER PERIPHERAL EQUIPMENT, NEC
# PROCESSING: CALCULATING & ACCOUNTING MACHINES (NO ELECTRONIC COMPUTERS)
# PROCESSING: OFFICE MACHINES, NEC
# PROCESSING: REFRIGERATION & SERVICE INDUSTRY MACHINERY
# PROCESSING: AIR-COND & WARM AIR HEATG EQUIP & COMM & INDL REFRIG EQUIP
# PROCESSING: MISC INDUSTRIAL & COMMERCIAL MACHINERY & EQUIPMENT
# PROCESSING: ELECTRONIC & OTHER ELECTRICAL EQUIPMENT (NO COMPUTER EQUIP)
# PROCESSING: POWER, DISTRIBUTION & SPECIALTY TRANSFORMERS
# PROCESSING: SWITCHGEAR & SWITCHBOARD APPARATUS
# PROCESSING: ELECTRICAL INDUSTRIAL APPARATUS
# PROCESSING: MOTORS & GENERATORS
# PROCESSING: HOUSEHOLD APPLIANCES
# PROCESSING: ELECTRIC HOUSEWARES & FANS
# PROCESSING: ELECTRIC LIGHTING & WIRING EQUIPMENT
# PROCESSING: HOUSEHOLD AUDIO & VIDEO EQUIPMENT
# PROCESSING: PHONOGRAPH RECORDS & PRERECORDED AUDIO TAPES & DISKS
# PROCESSING: TELEPHONE & TELEGRAPH APPARATUS
# PROCESSING: RADIO & TV BROADCASTING & COMMUNICATIONS EQUIPMENT
# PROCESSING: COMMUNICATIONS EQUIPMENT, NEC
# PROCESSING: ELECTRONIC COMPONENTS & ACCESSORIES
# PROCESSING: PRINTED CIRCUIT BOARDS
# PROCESSING: SEMICONDUCTORS & RELATED DEVICES
# PROCESSING: ELECTRONIC COILS, TRANSFORMERS & OTHER INDUCTORS
# PROCESSING: ELECTRONIC CONNECTORS
# PROCESSING: ELECTRONIC COMPONENTS, NEC
# PROCESSING: MISCELLANEOUS ELECTRICAL MACHINERY, EQUIPMENT & SUPPLIES
# PROCESSING: MAGNETIC & OPTICAL RECORDING MEDIA
# PROCESSING: MOTOR VEHICLES & PASSENGER CAR BODIES
# PROCESSING: TRUCK & BUS BODIES
# PROCESSING: MOTOR VEHICLE PARTS & ACCESSORIES
# PROCESSING: TRUCK TRAILERS
# PROCESSING: MOTOR HOMES
# PROCESSING: AIRCRAFT & PARTS
# PROCESSING: AIRCRAFT
# PROCESSING: AIRCRAFT ENGINES & ENGINE PARTS
# PROCESSING: AIRCRAFT PARTS & AUXILIARY EQUIPMENT, NEC
# PROCESSING: SHIP & BOAT BUILDING & REPAIRING
# PROCESSING: RAILROAD EQUIPMENT
# PROCESSING: MOTORCYCLES, BICYCLES & PARTS
# PROCESSING: GUIDED MISSILES & SPACE VEHICLES & PARTS
# PROCESSING: MISCELLANEOUS TRANSPORTATION EQUIPMENT
# PROCESSING: SEARCH, DETECTION, NAVAGATION, GUIDANCE, AERONAUTICAL SYS
# PROCESSING: LABORATORY APPARATUS & FURNITURE
# PROCESSING: AUTO CONTROLS FOR REGULATING RESIDENTIAL & COMML ENVIRONMENTS
# PROCESSING: INDUSTRIAL INSTRUMENTS FOR MEASUREMENT, DISPLAY, AND CONTROL
# PROCESSING: TOTALIZING FLUID METERS & COUNTING DEVICES
# PROCESSING: INSTRUMENTS FOR MEAS & TESTING OF ELECTRICITY & ELEC SIGNALS
# PROCESSING: LABORATORY ANALYTICAL INSTRUMENTS
# PROCESSING: OPTICAL INSTRUMENTS & LENSES
# PROCESSING: MEASURING & CONTROLLING DEVICES, NEC
# PROCESSING: SURGICAL & MEDICAL INSTRUMENTS & APPARATUS
# PROCESSING: ORTHOPEDIC, PROSTHETIC & SURGICAL APPLIANCES & SUPPLIES
# PROCESSING: DENTAL EQUIPMENT & SUPPLIES
# PROCESSING: X-RAY APPARATUS & TUBES & RELATED IRRADIATION APPARATUS
# PROCESSING: ELECTROMEDICAL & ELECTROTHERAPEUTIC APPARATUS
# PROCESSING: OPHTHALMIC GOODS
# PROCESSING: PHOTOGRAPHIC EQUIPMENT & SUPPLIES
# PROCESSING: WATCHES, CLOCKS, CLOCKWORK OPERATED DEVICES/PARTS
# PROCESSING: JEWELRY, SILVERWARE & PLATED WARE
# PROCESSING: JEWELRY, PRECIOUS METAL
# PROCESSING: MUSICAL INSTRUMENTS
# PROCESSING: DOLLS & STUFFED TOYS
# PROCESSING: GAMES, TOYS & CHILDREN'S VEHICLES (NO DOLLS & BICYCLES)
# PROCESSING: SPORTING & ATHLETIC GOODS, NEC
# PROCESSING: PENS, PENCILS & OTHER ARTISTS' MATERIALS
# PROCESSING: COSTUME JEWELRY & NOVELTIES
# PROCESSING: MISCELLANEOUS MANUFACTURING INDUSTRIES
# PROCESSING: RAILROADS, LINE-HAUL OPERATING
# PROCESSING: RAILROAD SWITCHING & TERMINAL ESTABLISHMENTS
# PROCESSING: LOCAL & SUBURBAN TRANSIT & INTERURBAN HWY PASSENGER TRANS
# PROCESSING: TRUCKING & COURIER SERVICES (NO AIR)
# PROCESSING: TRUCKING (NO LOCAL)
# PROCESSING: PUBLIC WAREHOUSING & STORAGE
# PROCESSING: TERMINAL MAINTENANCE FACILITIES FOR MOTOR FREIGHT TRANSPORT
# PROCESSING: WATER TRANSPORTATION
# PROCESSING: DEEP SEA FOREIGN TRANSPORTATION OF FREIGHT
# PROCESSING: AIR TRANSPORTATION, SCHEDULED
# PROCESSING: AIR COURIER SERVICES
# PROCESSING: AIR TRANSPORTATION, NONSCHEDULED
# PROCESSING: AIRPORTS, FLYING FIELDS & AIRPORT TERMINAL SERVICES
# PROCESSING: PIPE LINES (NO NATURAL GAS)
# PROCESSING: TRANSPORTATION SERVICES
# PROCESSING: ARRANGEMENT OF TRANSPORTATION OF FREIGHT & CARGO
# PROCESSING: RADIOTELEPHONE COMMUNICATIONS
# PROCESSING: TELEPHONE COMMUNICATIONS (NO RADIOTELEPHONE)
# PROCESSING: TELEGRAPH & OTHER MESSAGE COMMUNICATIONS
# PROCESSING: RADIO BROADCASTING STATIONS
# PROCESSING: TELEVISION BROADCASTING STATIONS
# PROCESSING: CABLE & OTHER PAY TELEVISION SERVICES
# PROCESSING: COMMUNICATIONS SERVICES, NEC
# PROCESSING: ELECTRIC, GAS & SANITARY SERVICES
# PROCESSING: ELECTRIC SERVICES
# PROCESSING: NATURAL GAS TRANSMISSION
# PROCESSING: NATURAL GAS TRANSMISISON & DISTRIBUTION
# PROCESSING: NATURAL GAS DISTRIBUTION
# PROCESSING: ELECTRIC & OTHER SERVICES COMBINED
# PROCESSING: GAS & OTHER SERVICES COMBINED
# PROCESSING: WATER SUPPLY
# PROCESSING: SANITARY SERVICES
# PROCESSING: REFUSE SYSTEMS
# PROCESSING: HAZARDOUS WASTE MANAGEMENT
# PROCESSING: STEAM & AIR-CONDITIONING SUPPLY
# PROCESSING: COGENERATION SERVICES & SMALL POWER PRODUCERS
# PROCESSING: WHOLESALE-DURABLE GOODS
# PROCESSING: WHOLESALE-MOTOR VEHICLES & MOTOR VEHICLE PARTS & SUPPLIES
# PROCESSING: WHOLESALE-MOTOR VEHICLE SUPPLIES & NEW PARTS
# PROCESSING: WHOLESALE-FURNITURE & HOME FURNISHINGS
# PROCESSING: WHOLESALE-LUMBER & OTHER CONSTRUCTION MATERIALS
# PROCESSING: WHOLESALE-LUMBER, PLYWOOD, MILLWORK & WOOD PANELS
# PROCESSING: WHOLESALE-PROFESSIONAL & COMMERCIAL EQUIPMENT & SUPPLIES
# PROCESSING: WHOLESALE-COMPUTERS & PERIPHERAL EQUIPMENT & SOFTWARE
# PROCESSING: WHOLESALE-MEDICAL, DENTAL & HOSPITAL EQUIPMENT & SUPPLIES
# PROCESSING: WHOLESALE-METALS & MINERALS (NO PETROLEUM)
# PROCESSING: WHOLESALE-METALS SERVICE CENTERS & OFFICES
# PROCESSING: WHOLESALE-ELECTRICAL APPARATUS & EQUIPMENT, WIRING SUPPLIES
# PROCESSING: WHOLESALE-ELECTRICAL APPLIANCES, TV & RADIO SETS
# PROCESSING: WHOLESALE-ELECTRONIC PARTS & EQUIPMENT, NEC
# PROCESSING: WHOLESALE-HARDWARE & PLUMBING & HEATING EQUIPMENT & SUPPLIES
# PROCESSING: WHOLESALE-HARDWARE
# PROCESSING: WHOLESALE-MACHINERY, EQUIPMENT & SUPPLIES
# PROCESSING: WHOLESALE-CONSTRUCTION & MINING (NO PETRO) MACHINERY & EQUIP
# PROCESSING: WHOLESALE-INDUSTRIAL MACHINERY & EQUIPMENT
# PROCESSING: WHOLESALE-MISC DURABLE GOODS
# PROCESSING: WHOLESALE-JEWELRY, WATCHES, PRECIOUS STONES & METALS
# PROCESSING: WHOLESALE-DURABLE GOODS, NEC
# PROCESSING: WHOLESALE-PAPER & PAPER PRODUCTS
# PROCESSING: WHOLESALE-DRUGS, PROPRIETARIES & DRUGGISTS' SUNDRIES
# Service unavailable (HTTP Code 502). Sleeping for 60 seconds.
# PROCESSING: WHOLESALE-APPAREL, PIECE GOODS & NOTIONS
# PROCESSING: WHOLESALE-GROCERIES & RELATED PRODUCTS
# PROCESSING: WHOLESALE-GROCERIES, GENERAL LINE
# PROCESSING: WHOLESALE-FARM PRODUCT RAW MATERIALS
# PROCESSING: WHOLESALE-CHEMICALS & ALLIED PRODUCTS
# PROCESSING: WHOLESALE-PETROLEUM BULK STATIONS & TERMINALS
# PROCESSING: WHOLESALE-PETROLEUM & PETROLEUM PRODUCTS (NO BULK STATIONS)
# PROCESSING: WHOLESALE-BEER, WINE & DISTILLED ALCOHOLIC BEVERAGES
# PROCESSING: WHOLESALE-MISCELLANEOUS NONDURABLE GOODS
# PROCESSING: RETAIL-BUILDING MATERIALS, HARDWARE, GARDEN SUPPLY
# PROCESSING: RETAIL-LUMBER & OTHER BUILDING MATERIALS DEALERS
# PROCESSING: RETAIL-MOBILE HOME DEALERS
# PROCESSING: RETAIL-DEPARTMENT STORES
# PROCESSING: RETAIL-VARIETY STORES
# PROCESSING: RETAIL-MISC GENERAL MERCHANDISE STORES
# PROCESSING: RETAIL-FOOD STORES
# PROCESSING: RETAIL-GROCERY STORES
# PROCESSING: RETAIL-CONVENIENCE STORES
# PROCESSING: RETAIL-AUTO DEALERS & GASOLINE STATIONS
# PROCESSING: RETAIL-AUTO & HOME SUPPLY STORES
# PROCESSING: RETAIL-APPAREL & ACCESSORY STORES
# PROCESSING: RETAIL-WOMEN'S CLOTHING STORES
# PROCESSING: RETAIL-FAMILY CLOTHING STORES
# PROCESSING: RETAIL-SHOE STORES
# PROCESSING: RETAIL-HOME FURNITURE, FURNISHINGS & EQUIPMENT STORES
# PROCESSING: RETAIL-FURNITURE STORES
# PROCESSING: RETAIL-RADIO, TV & CONSUMER ELECTRONICS STORES
# PROCESSING: RETAIL-COMPUTER & COMPUTER SOFTWARE STORES
# PROCESSING: RETAIL-RECORD & PRERECORDED TAPE STORES
# PROCESSING: RETAIL-EATING & DRINKING PLACES
# PROCESSING: RETAIL-EATING PLACES
# PROCESSING: RETAIL-MISCELLANEOUS RETAIL
# PROCESSING: RETAIL-DRUG STORES AND PROPRIETARY STORES
# PROCESSING: RETAIL-MISCELLANEOUS SHOPPING GOODS STORES
# PROCESSING: RETAIL-JEWELRY STORES
# PROCESSING: RETAIL-HOBBY, TOY & GAME SHOPS
# PROCESSING: RETAIL-NONSTORE RETAILERS
# PROCESSING: RETAIL-CATALOG & MAIL-ORDER HOUSES
# PROCESSING: RETAIL-RETAIL STORES, NEC
# PROCESSING: NATIONAL COMMERCIAL BANKS
# PROCESSING: STATE COMMERCIAL BANKS
# PROCESSING: COMMERCIAL BANKS, NEC
# PROCESSING: SAVINGS INSTITUTION, FEDERALLY CHARTERED
# PROCESSING: SAVINGS INSTITUTIONS, NOT FEDERALLY CHARTERED
# PROCESSING: FUNCTIONS RELATED TO DEPOSITORY BANKING, NEC
# PROCESSING: FEDERAL & FEDERALLY-SPONSORED CREDIT AGENCIES
# PROCESSING: PERSONAL CREDIT INSTITUTIONS
# PROCESSING: SHORT-TERM BUSINESS CREDIT INSTITUTIONS
# PROCESSING: MISCELLANEOUS BUSINESS CREDIT INSTITUTION
# PROCESSING: MORTGAGE BANKERS & LOAN CORRESPONDENTS
# PROCESSING: LOAN BROKERS
# PROCESSING: FINANCE LESSORS
# PROCESSING: ASSET-BACKED SECURITIES
# PROCESSING: FINANCE SERVICES
# PROCESSING: SECURITY & COMMODITY BROKERS, DEALERS, EXCHANGES & SERVICES
# PROCESSING: SECURITY BROKERS, DEALERS & FLOTATION COMPANIES
# PROCESSING: COMMODITY CONTRACTS BROKERS & DEALERS
# PROCESSING: INVESTMENT ADVICE
# PROCESSING: LIFE INSURANCE
# PROCESSING: ACCIDENT & HEALTH INSURANCE
# PROCESSING: HOSPITAL & MEDICAL SERVICE PLANS
# PROCESSING: FIRE, MARINE & CASUALTY INSURANCE
# PROCESSING: SURETY INSURANCE
# PROCESSING: TITLE INSURANCE
# PROCESSING: INSURANCE CARRIERS, NEC
# PROCESSING: INSURANCE AGENTS, BROKERS & SERVICE
# PROCESSING: REAL ESTATE
# PROCESSING: REAL ESTATE OPERATORS (NO DEVELOPERS) & LESSORS
# PROCESSING: OPERATORS OF NONRESIDENTIAL BUILDINGS
# PROCESSING: OPERATORS OF APARTMENT BUILDINGS
# PROCESSING: LESSORS OF REAL PROPERTY, NEC
# PROCESSING: REAL ESTATE AGENTS & MANAGERS (FOR OTHERS)
# PROCESSING: REAL ESTATE DEALERS (FOR THEIR OWN ACCOUNT)
# PROCESSING: LAND SUBDIVIDERS & DEVELOPERS (NO CEMETERIES)
# PROCESSING: BLANK CHECKS
# PROCESSING: OIL ROYALTY TRADERS
# PROCESSING: PATENT OWNERS & LESSORS
# PROCESSING: MINERAL ROYALTY TRADERS
# PROCESSING: REAL ESTATE INVESTMENT TRUSTS
# PROCESSING: INVESTORS, NEC
# PROCESSING: HOTELS, ROOMING HOUSES, CAMPS & OTHER LODGING PLACES
# PROCESSING: HOTELS & MOTELS
# PROCESSING: SERVICES-PERSONAL SERVICES
# PROCESSING: SERVICES-ADVERTISING
# PROCESSING: SERVICES-ADVERTISING AGENCIES
# PROCESSING: SERVICES-CONSUMER CREDIT REPORTING, COLLECTION AGENCIES
# PROCESSING: SERVICES-MAILING, REPRODUCTION, COMMERCIAL ART & PHOTOGRAPHY
# PROCESSING: SERVICES-DIRECT MAIL ADVERTISING SERVICES
# PROCESSING: SERVICES-TO DWELLINGS & OTHER BUILDINGS
# PROCESSING: SERVICES-MISCELLANEOUS EQUIPMENT RENTAL & LEASING
# PROCESSING: SERVICES-EQUIPMENT RENTAL & LEASING, NEC
# PROCESSING: SERVICES-EMPLOYMENT AGENCIES
# PROCESSING: SERVICES-HELP SUPPLY SERVICES
# PROCESSING: SERVICES-COMPUTER PROGRAMMING, DATA PROCESSING, ETC.
# PROCESSING: SERVICES-COMPUTER PROGRAMMING SERVICES
# PROCESSING: SERVICES-PREPACKAGED SOFTWARE
# PROCESSING: SERVICES-COMPUTER INTEGRATED SYSTEMS DESIGN
# PROCESSING: SERVICES-COMPUTER PROCESSING & DATA PREPARATION
# PROCESSING: SERVICES-COMPUTER RENTAL & LEASING
# PROCESSING: SERVICES-MISCELLANEOUS BUSINESS SERVICES
# PROCESSING: SERVICES-DETECTIVE, GUARD & ARMORED CAR SERVICES
# PROCESSING: SERVICES-PHOTOFINISHING LABORATORIES
# PROCESSING: SERVICES-TELEPHONE INTERCONNECT SYSTEMS
# PROCESSING: SERVICES-BUSINESS SERVICES, NEC
# PROCESSING: SERVICES-AUTOMOTIVE REPAIR, SERVICES & PARKING
# PROCESSING: SERVICES-AUTO RENTAL & LEASING (NO DRIVERS)
# PROCESSING: SERVICES-MISCELLANEOUS REPAIR SERVICES
# PROCESSING: SERVICES-MOTION PICTURE & VIDEO TAPE PRODUCTION
# PROCESSING: SERVICES-ALLIED TO MOTION PICTURE PRODUCTION
# PROCESSING: SERVICES-MOTION PICTURE & VIDEO TAPE DISTRIBUTION
# PROCESSING: SERVICES-ALLIED TO MOTION PICTURE DISTRIBUTION
# PROCESSING: SERVICES-MOTION PICTURE THEATERS
# PROCESSING: SERVICES-VIDEO TAPE RENTAL
# PROCESSING: SERVICES-AMUSEMENT & RECREATION SERVICES
# PROCESSING: SERVICES-RACING, INCLUDING TRACK OPERATION
# PROCESSING: SERVICES-MISCELLANEOUS AMUSEMENT & RECREATION
# PROCESSING: SERVICES-MEMBERSHIP SPORTS & RECREATION CLUBS
# PROCESSING: SERVICES-HEALTH SERVICES
# PROCESSING: SERVICES-OFFICES & CLINICS OF DOCTORS OF MEDICINE
# PROCESSING: SERVICES-NURSING & PERSONAL CARE FACILITIES
# PROCESSING: SERVICES-SKILLED NURSING CARE FACILITIES
# PROCESSING: SERVICES-HOSPITALS
# PROCESSING: SERVICES-GENERAL MEDICAL & SURGICAL HOSPITALS, NEC
# PROCESSING: SERVICES-MEDICAL LABORATORIES
# PROCESSING: SERVICES-HOME HEALTH CARE SERVICES
# PROCESSING: SERVICES-MISC HEALTH & ALLIED SERVICES, NEC
# PROCESSING: SERVICES-SPECIALTY OUTPATIENT FACILITIES, NEC
# PROCESSING: SERVICES-LEGAL SERVICES
# PROCESSING: SERVICES-EDUCATIONAL SERVICES
# PROCESSING: SERVICES-SOCIAL SERVICES
# PROCESSING: SERVICES-CHILD DAY CARE SERVICES
# PROCESSING: SERVICES-MEMBERSHIP ORGANIZATIONS
# PROCESSING: SERVICES-ENGINEERING, ACCOUNTING, RESEARCH, MANAGEMENT
# PROCESSING: SERVICES-ENGINEERING SERVICES
# PROCESSING: SERVICES-COMMERCIAL PHYSICAL & BIOLOGICAL RESEARCH
# PROCESSING: SERVICES-TESTING LABORATORIES
# PROCESSING: SERVICES-MANAGEMENT SERVICES
# PROCESSING: SERVICES-MANAGEMENT CONSULTING SERVICES
# PROCESSING: SERVICES-FACILITIES SUPPORT MANAGEMENT SERVICES
# PROCESSING: AMERICAN DEPOSITARY RECEIPTS
# PROCESSING: FOREIGN GOVERNMENTS
# PROCESSING: SERVICES-SERVICES, NEC
# PROCESSING: INTERNATIONAL AFFAIRS
# PROCESSING: NON-OPERATING ESTABLISHMENTS

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=30a1da16-8d37-4863-b767-04fc5292d9a6' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
